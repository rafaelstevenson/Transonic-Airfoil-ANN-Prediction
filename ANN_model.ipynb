# %% [markdown]
# # Transonic Airfoil Aerodynamic Coefficients Prediction using Artificial Neural Network

# %% [markdown]
# In this notebook, an artificial neural network being modeled to predict the aerodynamic coefficients of an airfoil that flies at a nominal condition of __Mach Number M = 0.729__ where the data of varying M and __angle of attack α__ results in various __lift coefficient Cl__, __drag coefficient Cd__ and the pressure coefficient at the center of the upper surface of the airfoil __Cp__ using _Tensorflow and Keras_.
#
# The data were taken from the following reference: Pramudita Satria Palar, Lavi Rizki Zuhal, and Koji Shimoyama."Gaussian Process Surrogate Model with Composite Kernel Learning for Engineering Design." _AIAA Journal_ 58, no. 4 (2020):1864-1880.
#
# _Notebook made to explore simple Artificial Neural Network, Rafael S_

# %% [markdown]
# ### Importing required packages

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Importing Dataset

# %%
df = pd.read_csv('transonic_airfoil_data_set.csv').drop(columns = 'No')

# %%
df
# Out:
#             M       AoA        Cl        Cd        Cp
# 0    0.727928  2.449037  0.740129  0.013330 -0.911550
# 1    0.736393  2.389265  0.736667  0.015423 -1.218775
# 2    0.731969  2.251332  0.709717  0.013156 -1.122496
# 3    0.735015  2.388274  0.736197  0.014977 -1.214580
# 4    0.725872  2.448004  0.737060  0.012857 -0.697603
# ..        ...       ...       ...       ...       ...
# 961  0.735045  2.165183  0.698091  0.013423 -1.164278
# 962  0.726631  2.204177  0.693080  0.011845 -0.626338
# 963  0.727602  2.113649  0.678026  0.011613 -0.634598
# 964  0.738150  2.251622  0.715140  0.014969 -1.198659
# 965  0.728880  2.491825  0.749115  0.013877 -1.037020
#
# [966 rows x 5 columns]

# %% [markdown]
# ### Data Plot

# %% [markdown]
# Plotting the data to have a better visualization of our data distribution and linearity.

# %% [markdown]
# #### Lift Coefficient Cl Plot

# %%
figcl = plt.figure(figsize = [6,6])
clplot = Axes3D(figcl)
clplot.scatter(df['M'], df['AoA'], df['Cl'])
clplot.set_xlabel('Mach Number')
clplot.set_ylabel('Angle of Attack (degree)')
clplot.set_zlabel('Cl')
plt.show()

plt.scatter(df['M'], df['Cl'], alpha = 0.3)
plt.xlabel('Mach Number')
plt.ylabel('Cl')
plt.title('Cl vs Mach Number')
plt.show()

plt.scatter(df['AoA'], df['Cl'], alpha = 0.3)
plt.xlabel('Angle of Attack (degree)')
plt.ylabel('Cl')
plt.title('Cl vs AoA')
plt.show()

# %% [markdown]
# #### Drag Coefficient Cd Plot

# %%
figcd = plt.figure(figsize = [6,6])
cdplot = Axes3D(figcd)
cdplot.scatter(df['M'], df['AoA'], df['Cd'], c = 'r', alpha = 0.3)
cdplot.set_xlabel('Mach Number')
cdplot.set_ylabel('Angle of Attack (degree)')
cdplot.set_zlabel('Cd')
plt.show()

plt.scatter(df['M'], df['Cd'], alpha = 0.2, c = 'r')
plt.xlabel('Mach Number')
plt.ylabel('Cd')
plt.title('Cd vs Mach Number')
plt.show()

plt.scatter(df['AoA'], df['Cd'], alpha = 0.2, c = 'r')
plt.xlabel('Angle of Attack (degree)')
plt.ylabel('Cd')
plt.title('Cd vs AoA')
plt.show()

# %% [markdown]
# #### Pressure Coefficient Cp Plot

# %%
figcp = plt.figure(figsize = [6,6])
cpplot = Axes3D(figcp)
cpplot.scatter(df['M'], df['AoA'], df['Cp'], c = 'g')
cpplot.set_xlabel('Mach Number')
cpplot.set_ylabel('Angle of Attack (degree)')
cpplot.set_zlabel('Cp')
plt.show()

plt.scatter(df['M'], df['Cp'], alpha = 0.3, c = 'g')
plt.xlabel('Mach Number')
plt.ylabel('Cp')
plt.title('Cp vs Mach Number')
plt.show()

plt.scatter(df['AoA'], df['Cp'], alpha = 0.3, c = 'g')
plt.xlabel('Angle of Attack (degree)')
plt.ylabel('Cp')
plt.title('Cp vs AoA')
plt.show()

# %% [markdown]
# ### Correlation Coefficient

# %% [markdown]
# Checking the Pearson's correlation coefficient to measure the statistical relationship, or association, between the variables.

# %%
df_heatmap = sns.heatmap(df.corr(), annot = True, cmap = 'coolwarm')

# %% [markdown]
# ### Input and Output Data
# Defining the input data and the output data.

# %%
X = df.loc[:, ['M', 'AoA']]
y = df.loc[:, ['Cl', 'Cd', 'Cp']]

# %%
X #Input Data
# Out:
#             M       AoA
# 0    0.727928  2.449037
# 1    0.736393  2.389265
# 2    0.731969  2.251332
# 3    0.735015  2.388274
# 4    0.725872  2.448004
# ..        ...       ...
# 961  0.735045  2.165183
# 962  0.726631  2.204177
# 963  0.727602  2.113649
# 964  0.738150  2.251622
# 965  0.728880  2.491825
#
# [966 rows x 2 columns]

# %%
y #Output Data
# Out:
#            Cl        Cd        Cp
# 0    0.740129  0.013330 -0.911550
# 1    0.736667  0.015423 -1.218775
# 2    0.709717  0.013156 -1.122496
# 3    0.736197  0.014977 -1.214580
# 4    0.737060  0.012857 -0.697603
# ..        ...       ...       ...
# 961  0.698091  0.013423 -1.164278
# 962  0.693080  0.011845 -0.626338
# 963  0.678026  0.011613 -0.634598
# 964  0.715140  0.014969 -1.198659
# 965  0.749115  0.013877 -1.037020
#
# [966 rows x 3 columns]

# %% [markdown]
# ### Dataset Split (Training and Validation Data)
# Splitting the dataset by random and evenly distributed for the training and validation dataset.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 29)

# %% [markdown]
# Plotting to visualize the dataset split result.

# %%
# Creating figure
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(X_train['M'], X_train['AoA'], y_train['Cl'], color = "green", alpha=0.3, label='Train Data')
visual_split.scatter3D(X_test['M'], X_test['AoA'], y_test['Cl'], color = "red",alpha=0.5, label='Test Data')
plt.title("Train and Test Dataset")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

# %% [markdown]
# ## Normalizing The Data

# %% [markdown]
# Normalization ensures that the magnitude of the values that a feature assumes are more or less the same.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scalery = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

y_train = scalery.fit_transform(y_train)
y_test = scalery.transform(y_test)

# %% [markdown]
# ## Modeling The Artificial Neural Network

# %% [markdown]
# The activation function for the hidden layer of the network is using the Rectified Linear Unit (ReLU) function as it is a simple, fast and observed to converge much more quickly and reliably.
#
# The Dropout algorithm is commented out as it doesn't provide improvements after a few trainings, and early stopping method is being used instead to avoid overfitting our neural network to the dataset.
#
# The optimizer is the adam optimizer as it provides an adaptive learning rate to optimize better.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
NNmodel = Sequential()

NNmodel.add(Dense(6,activation='relu')) #Hidden Layer
#NNmodel.add(Dropout(0.2))
NNmodel.add(Dense(6,activation='relu')) #Hidden Layer
#NNmodel.add(Dropout(0.2))
NNmodel.add(Dense(6,activation='relu')) #Hidden Layer
#NNmodel.add(Dropout(0.2))

NNmodel.add(Dense(units = 3,activation='linear')) #Output Layer

NNmodel.compile(loss='mse', optimizer='adam')

# %% [markdown]
# ### Early Stopping

# %% [markdown]
# To avoid overfitting during the training of the neural network, early stopping method is being added. Early stopping is a form of regularization used to avoid overfitting when training a learner with an iterative method.

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=45)

# %% [markdown]
# ### Training The Artificial Neural Network

# %%
NNmodel.fit(x=X_train, y=y_train, epochs=1000, validation_data=(X_test,y_test), callbacks=[early_stop])
# Out:
# Epoch 1/1000
# 25/25 [==============================] - 1s 9ms/step - loss: 0.2326 - val_loss: 0.1744
# Epoch 2/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1581 - val_loss: 0.1257
# Epoch 3/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1109 - val_loss: 0.0976
# Epoch 4/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0915 - val_loss: 0.0807
# Epoch 5/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0750 - val_loss: 0.0706
# Epoch 6/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0660 - val_loss: 0.0649
# Epoch 7/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0606 - val_loss: 0.0616
# Epoch 8/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0588 - val_loss: 0.0598
# Epoch 9/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0555 - val_loss: 0.0586
# Epoch 10/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0550 - val_loss: 0.0578
# Epoch 11/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0542 - val_loss: 0.0569
# Epoch 12/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0529 - val_loss: 0.0561
# Epoch 13/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0523 - val_loss: 0.0553
# Epoch 14/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0525 - val_loss: 0.0544
# Epoch 15/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0523 - val_loss: 0.0536
# Epoch 16/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0503 - val_loss: 0.0528
# Epoch 17/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0496 - val_loss: 0.0520
# Epoch 18/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0487 - val_loss: 0.0510
# Epoch 19/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0485 - val_loss: 0.0500
# Epoch 20/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0459 - val_loss: 0.0489
# Epoch 21/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0448 - val_loss: 0.0475
# Epoch 22/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0458 - val_loss: 0.0460
# Epoch 23/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0428 - val_loss: 0.0445
# Epoch 24/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0408 - val_loss: 0.0424
# Epoch 25/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0409 - val_loss: 0.0401
# Epoch 26/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0377 - val_loss: 0.0379
# Epoch 27/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0362 - val_loss: 0.0351
# Epoch 28/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0353 - val_loss: 0.0327
# Epoch 29/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0301 - val_loss: 0.0299
# Epoch 30/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0285 - val_loss: 0.0273
# Epoch 31/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0247 - val_loss: 0.0250
# Epoch 32/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0222 - val_loss: 0.0231
# Epoch 33/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0208 - val_loss: 0.0209
# Epoch 34/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0185 - val_loss: 0.0190
# Epoch 35/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0165 - val_loss: 0.0173
# Epoch 36/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0159 - val_loss: 0.0160
# Epoch 37/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0141 - val_loss: 0.0149
# Epoch 38/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0142 - val_loss: 0.0133
# Epoch 39/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0120 - val_loss: 0.0126
# Epoch 40/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0117 - val_loss: 0.0117
# Epoch 41/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0102 - val_loss: 0.0111
# Epoch 42/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0109
# Epoch 43/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 44/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 45/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0086 - val_loss: 0.0094
# Epoch 46/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0078 - val_loss: 0.0090
# Epoch 47/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.0086
# Epoch 48/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 49/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.0083
# Epoch 50/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0078
# Epoch 51/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0072
# Epoch 52/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0067
# Epoch 53/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0064
# Epoch 54/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 55/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0061
# Epoch 56/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0058
# Epoch 57/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0056
# Epoch 58/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0054
# Epoch 59/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 60/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0053
# Epoch 61/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 62/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 63/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0050
# Epoch 64/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0049
# Epoch 65/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0050
# Epoch 66/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 67/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0048
# Epoch 68/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0048
# Epoch 69/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 70/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0046
# Epoch 71/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 72/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 73/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0045
# Epoch 74/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 75/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0045
# Epoch 76/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 77/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 78/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0043
# Epoch 79/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0044
# Epoch 80/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0041
# Epoch 81/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 82/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 83/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 84/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 85/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0040
# Epoch 86/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 87/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0039
# Epoch 88/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 89/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 90/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 91/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 92/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 93/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 94/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 95/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 96/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 97/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 98/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 99/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 100/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 101/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 102/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0030
# Epoch 103/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 104/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 105/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 106/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0028
# Epoch 107/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0028
# Epoch 108/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 109/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.
1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2632e-04 - val_loss: 1.6090e-04
# Epoch 623/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2160e-04 - val_loss: 1.6032e-04
# Epoch 624/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4030e-04 - val_loss: 1.6167e-04
# Epoch 625/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3159e-04 - val_loss: 1.8180e-04
# Epoch 626/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5719e-04 - val_loss: 1.5553e-04
# Epoch 627/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2918e-04 - val_loss: 1.6360e-04
# Epoch 628/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3500e-04 - val_loss: 1.5465e-04
# Epoch 629/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2299e-04 - val_loss: 1.5920e-04
# Epoch 630/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3794e-04 - val_loss: 1.6401e-04
# Epoch 631/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2218e-04 - val_loss: 1.6089e-04
# Epoch 632/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2729e-04 - val_loss: 1.5544e-04
# Epoch 633/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3921e-04 - val_loss: 1.5877e-04
# Epoch 634/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3576e-04 - val_loss: 1.5428e-04
# Epoch 635/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0920e-04 - val_loss: 1.5405e-04
# Epoch 636/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2201e-04 - val_loss: 1.6985e-04
# Epoch 637/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3517e-04 - val_loss: 1.8450e-04
# Epoch 638/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5115e-04 - val_loss: 1.5551e-04
# Epoch 639/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2694e-04 - val_loss: 1.5639e-04
# Epoch 640/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3585e-04 - val_loss: 1.5516e-04
# Epoch 641/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1113e-04 - val_loss: 1.6402e-04
# Epoch 642/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3068e-04 - val_loss: 1.5343e-04
# Epoch 643/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4273e-04 - val_loss: 1.7468e-04
# Epoch 644/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4503e-04 - val_loss: 1.6252e-04
# Epoch 645/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1303e-04 - val_loss: 1.5775e-04
# Epoch 646/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2195e-04 - val_loss: 1.5641e-04
# Epoch 647/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3464e-04 - val_loss: 1.8666e-04
# Epoch 648/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4230e-04 - val_loss: 1.6712e-04
# Epoch 649/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3467e-04 - val_loss: 1.6011e-04
# Epoch 650/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1706e-04 - val_loss: 2.0726e-04
# Epoch 651/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0786e-04 - val_loss: 1.7138e-04
# Epoch 652/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3875e-04 - val_loss: 1.6542e-04
# Epoch 653/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2969e-04 - val_loss: 1.5409e-04
# Epoch 654/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1410e-04 - val_loss: 1.6538e-04
# Epoch 655/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4565e-04 - val_loss: 1.6333e-04
# Epoch 00655: early stopping

# %% [markdown]
# ### Plotting The Losses During Training

# %%
losses = pd.DataFrame(NNmodel.history.history)
losses[['loss', 'val_loss']].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Predicting On The Test Dataset

# %%
predictions = NNmodel.predict(X_test)

# %%
predictions = scalery.inverse_transform(predictions)
y_test = scalery.inverse_transform(y_test)

# %% [markdown]
# ### Mean Squared Error and Mean Absolute Error of the Prediction Results

# %%
mse_cl = mean_squared_error(y_test[:,0], predictions[:,0])
print(f"Mean Squared Error for Cl: {mse_cl}")
mae_cl = np.sum(np.absolute(y_test[:,0]- predictions[:,0]))/len(y_test)
print(f"Mean Absolute Error for Cl: {mae_cl}\n")
mse_cd = mean_squared_error(y_test[:,1], predictions[:,1])
print(f"Mean Squared Error for Cd: {mse_cd}")
mae_cd = np.sum(np.absolute(y_test[:,1]- predictions[:,1]))/len(y_test)
print(f"Mean Absolute Error for Cd: {mae_cd}\n")
mse_cp = mean_squared_error(y_test[:,2], predictions[:,2])
print(f"Mean Squared Error for Cp: {mse_cp}")
mae_cp = np.sum(np.absolute(y_test[:,2]- predictions[:,2]))/len(y_test)
print(f"Mean Absolute Error for Cp: {mae_cp}\n")
# Out:
# Mean Squared Error for Cl: 1.6544486485025377e-06
# Mean Absolute Error for Cl: 0.0006105263979213741
#
# Mean Squared Error for Cd: 2.7185832047524228e-08
# Mean Absolute Error for Cd: 0.00010999488217836801
#
# Mean Squared Error for Cp: 9.791787121356306e-05
# Mean Absolute Error for Cp: 0.007098041198750123

# %% [markdown]
# ### Predictions vs Ground Truth Plots

# %%
###############################Cl
# Creating figure Cl
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], predictions[:,0], color = "black", alpha=1, label='Predictions', marker='x')
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], y_test[:,0], color = "blue", alpha=0.6, label='Ground Truth')
plt.title("Cl Prediction vs Ground Truth")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,0], predictions[:,0], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,0], y_test[:,0], color = "blue", alpha=0.6, label='Ground Truth')
plt.xlabel('Mach Number')
plt.ylabel('Cl')
plt.title('Cl vs Mach Number')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,1], predictions[:,0], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,1], y_test[:,0], color = "blue", alpha=0.6, label='Ground Truth')
plt.xlabel('AoA')
plt.ylabel('Cl')
plt.title('Cl vs AoA')
plt.legend()
plt.show()

##############################Cd
# Creating figure Cd
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], predictions[:,1], color = "black", alpha=1, label='Predictions', marker='x')
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], y_test[:,1], color = "red", alpha=0.6, label='Ground Truth')
plt.title("Cd Prediction vs Ground Truth")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,0], predictions[:,1], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,0], y_test[:,1], color = "red", alpha=0.6, label='Ground Truth')
plt.xlabel('Mach Number')
plt.ylabel('Cd')
plt.title('Cd vs Mach Number')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,1], predictions[:,1], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,1], y_test[:,1], color = "red", alpha=0.6, label='Ground Truth')
plt.xlabel('AoA')
plt.ylabel('Cd')
plt.title('Cd vs AoA')
plt.legend()
plt.show()

##############################Cp
# Creating figure Cp
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], predictions[:,2], color = "black", alpha=1, label='Predictions', marker='x')
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], y_test[:,2], color = "g", alpha=0.6, label='Ground Truth')
plt.title("Cp Prediction vs Ground Truth")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,0], predictions[:,2], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,0], y_test[:,2], color = "green", alpha=0.6, label='Ground Truth')
plt.xlabel('Mach Number')
plt.ylabel('Cd')
plt.title('Cd vs Mach Number')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,1], predictions[:,2], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,1], y_test[:,2], color = "green", alpha=0.6, label='Ground Truth')
plt.xlabel('AoA')
plt.ylabel('Cd')
plt.title('Cd vs AoA')
plt.legend()
plt.show()

# %% [markdown]
# ### Sampling Predictions

# %%
sample_number = 6
#alldata=len(predictions)
print("[Cl Cd Cp]")
for i in range (sample_number):
    print(f"Sample Data {i+1}: {y_test[i]}")
    print(f"Prediction {i+1}: {predictions[i]}")
    error = np.abs(y_test[i]-predictions[i])
    print(f"error: {error}\n--------------------------------------------------")
# Out:
# [Cl Cd Cp]
# Sample Data 1: [ 0.683542  0.011203 -0.686882]
# Prediction 1: [ 0.6837827  0.0113031 -0.6831254]
# error: [0.0002407  0.0001001  0.00375662]
# --------------------------------------------------
# Sample Data 2: [ 0.73528   0.013844 -1.152869]
# Prediction 2: [ 0.735423    0.01394546 -1.1693057 ]
# error: [0.00014303 0.00010146 0.01643668]
# --------------------------------------------------
# Sample Data 3: [ 0.675539  0.01153  -0.624721]
# Prediction 3: [ 0.6762829   0.01145281 -0.6257425 ]
# error: [7.43882690e-04 7.71900925e-05 1.02149506e-03]
# --------------------------------------------------
# Sample Data 4: [ 0.652789  0.010931 -0.671232]
# Prediction 4: [ 0.6532734   0.01084147 -0.67193794]
# error: [4.84403645e-04 8.95297883e-05 7.05942505e-04]
# --------------------------------------------------
# Sample Data 5: [ 0.723796  0.014562 -1.201687]
# Prediction 5: [ 0.72333044  0.01473194 -1.1941031 ]
# error: [0.00046556 0.00016994 0.00758388]
# --------------------------------------------------
# Sample Data 6: [ 0.729271  0.015041 -1.210357]
# Prediction 6: [ 0.7293357  0.0152362 -1.2063601]
# error: [6.47253075e-05 1.95197039e-04 3.99689830e-03]
# --------------------------------------------------
