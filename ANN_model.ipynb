# %% [markdown]
# # Transonic Airfoil Aerodynamic Coefficients Prediction using Artificial Neural Network

# %% [markdown]
# In this notebook, an artificial neural network being modeled to predict the aerodynamic coefficients of an airfoil that flies at a nominal condition of __Mach Number M = 0.729__ where the data of varying M and __angle of attack α__ results in various __lift coefficient Cl__, __drag coefficient Cd__ and the pressure coefficient at the center of the upper surface of the airfoil __Cp__ using _Tensorflow and Keras_.
#
# The data were taken from the following reference: Pramudita Satria Palar, Lavi Rizki Zuhal, and Koji Shimoyama."Gaussian Process Surrogate Model with Composite Kernel Learning for Engineering Design." _AIAA Journal_ 58, no. 4 (2020):1864-1880.
#
# _Notebook made to explore simple Artificial Neural Network, Rafael S_

# %% [markdown]
# ### Importing required packages

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Importing Dataset

# %%
df = pd.read_csv('transonic_airfoil_data_set.csv').drop(columns = 'No')

# %%
df
# Out:
#             M       AoA        Cl        Cd        Cp
# 0    0.727928  2.449037  0.740129  0.013330 -0.911550
# 1    0.736393  2.389265  0.736667  0.015423 -1.218775
# 2    0.731969  2.251332  0.709717  0.013156 -1.122496
# 3    0.735015  2.388274  0.736197  0.014977 -1.214580
# 4    0.725872  2.448004  0.737060  0.012857 -0.697603
# ..        ...       ...       ...       ...       ...
# 961  0.735045  2.165183  0.698091  0.013423 -1.164278
# 962  0.726631  2.204177  0.693080  0.011845 -0.626338
# 963  0.727602  2.113649  0.678026  0.011613 -0.634598
# 964  0.738150  2.251622  0.715140  0.014969 -1.198659
# 965  0.728880  2.491825  0.749115  0.013877 -1.037020
#
# [966 rows x 5 columns]

# %% [markdown]
# ### Data Plot

# %% [markdown]
# Plotting the data to have a better visualization of our data distribution and linearity.

# %% [markdown]
# #### Lift Coefficient Cl Plot

# %%
figcl = plt.figure(figsize = [6,6])
clplot = Axes3D(figcl)
clplot.scatter(df['M'], df['AoA'], df['Cl'])
clplot.set_xlabel('Mach Number')
clplot.set_ylabel('Angle of Attack (degree)')
clplot.set_zlabel('Cl')
plt.show()

plt.scatter(df['M'], df['Cl'], alpha = 0.3)
plt.xlabel('Mach Number')
plt.ylabel('Cl')
plt.title('Cl vs Mach Number')
plt.show()

plt.scatter(df['AoA'], df['Cl'], alpha = 0.3)
plt.xlabel('Angle of Attack (degree)')
plt.ylabel('Cl')
plt.title('Cl vs AoA')
plt.show()

# %% [markdown]
# #### Drag Coefficient Cd Plot

# %%
figcd = plt.figure(figsize = [6,6])
cdplot = Axes3D(figcd)
cdplot.scatter(df['M'], df['AoA'], df['Cd'], c = 'r', alpha = 0.3)
cdplot.set_xlabel('Mach Number')
cdplot.set_ylabel('Angle of Attack (degree)')
cdplot.set_zlabel('Cd')
plt.show()

plt.scatter(df['M'], df['Cd'], alpha = 0.2, c = 'r')
plt.xlabel('Mach Number')
plt.ylabel('Cd')
plt.title('Cd vs Mach Number')
plt.show()

plt.scatter(df['AoA'], df['Cd'], alpha = 0.2, c = 'r')
plt.xlabel('Angle of Attack (degree)')
plt.ylabel('Cd')
plt.title('Cd vs AoA')
plt.show()

# %% [markdown]
# #### Pressure Coefficient Cp Plot

# %%
figcp = plt.figure(figsize = [6,6])
cpplot = Axes3D(figcp)
cpplot.scatter(df['M'], df['AoA'], df['Cp'], c = 'g')
cpplot.set_xlabel('Mach Number')
cpplot.set_ylabel('Angle of Attack (degree)')
cpplot.set_zlabel('Cp')
plt.show()

plt.scatter(df['M'], df['Cp'], alpha = 0.3, c = 'g')
plt.xlabel('Mach Number')
plt.ylabel('Cp')
plt.title('Cp vs Mach Number')
plt.show()

plt.scatter(df['AoA'], df['Cp'], alpha = 0.3, c = 'g')
plt.xlabel('Angle of Attack (degree)')
plt.ylabel('Cp')
plt.title('Cp vs AoA')
plt.show()

# %% [markdown]
# ### Correlation Coefficient

# %% [markdown]
# Checking the Pearson's correlation coefficient to measure the statistical relationship, or association, between the variables.

# %%
df_heatmap = sns.heatmap(df.corr(), annot = True, cmap = 'coolwarm')

# %% [markdown]
# ### Input and Output Data
# Defining the input data and the output data.

# %%
X = df.loc[:, ['M', 'AoA']]
y = df.loc[:, ['Cl', 'Cd', 'Cp']]

# %%
X #Input Data
# Out:
#             M       AoA
# 0    0.727928  2.449037
# 1    0.736393  2.389265
# 2    0.731969  2.251332
# 3    0.735015  2.388274
# 4    0.725872  2.448004
# ..        ...       ...
# 961  0.735045  2.165183
# 962  0.726631  2.204177
# 963  0.727602  2.113649
# 964  0.738150  2.251622
# 965  0.728880  2.491825
#
# [966 rows x 2 columns]

# %%
y #Output Data
# Out:
#            Cl        Cd        Cp
# 0    0.740129  0.013330 -0.911550
# 1    0.736667  0.015423 -1.218775
# 2    0.709717  0.013156 -1.122496
# 3    0.736197  0.014977 -1.214580
# 4    0.737060  0.012857 -0.697603
# ..        ...       ...       ...
# 961  0.698091  0.013423 -1.164278
# 962  0.693080  0.011845 -0.626338
# 963  0.678026  0.011613 -0.634598
# 964  0.715140  0.014969 -1.198659
# 965  0.749115  0.013877 -1.037020
#
# [966 rows x 3 columns]

# %% [markdown]
# ### Dataset Split (Training and Validation Data)
# Splitting the dataset by random and evenly distributed for the training and validation dataset.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 29)

# %% [markdown]
# Plotting to visualize the dataset split result.

# %%
# Creating figure
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(X_train['M'], X_train['AoA'], y_train['Cl'], color = "green", alpha=0.3, label='Train Data')
visual_split.scatter3D(X_test['M'], X_test['AoA'], y_test['Cl'], color = "red",alpha=0.5, label='Test Data')
plt.title("Train and Test Dataset")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

# %% [markdown]
# ## Normalizing The Data

# %% [markdown]
# Normalization ensures that the magnitude of the values that a feature assumes are more or less the same.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scalery = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

y_train = scalery.fit_transform(y_train)
y_test = scalery.transform(y_test)

# %% [markdown]
# ## Modeling The Artificial Neural Network

# %% [markdown]
# The activation function for the hidden layer of the network is using the Rectified Linear Unit (ReLU) function as it is a simple, fast and observed to converge much more quickly and reliably.
#
# The Dropout algorithm is commented out as it doesn't provide improvements after a few trainings, and early stopping method is being used instead to avoid overfitting our neural network to the dataset.
#
# The optimizer is the adam optimizer as it provides an adaptive learning rate to optimize better.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
NNmodel = Sequential()

NNmodel.add(Dense(6,activation='relu')) #Hidden Layer
#NNmodel.add(Dropout(0.2))
NNmodel.add(Dense(6,activation='relu')) #Hidden Layer
#NNmodel.add(Dropout(0.2))
NNmodel.add(Dense(6,activation='relu')) #Hidden Layer
#NNmodel.add(Dropout(0.2))

NNmodel.add(Dense(units = 3,activation='linear')) #Output Layer

NNmodel.compile(loss='mse', optimizer='adam')

# %% [markdown]
# ### Early Stopping

# %% [markdown]
# To avoid overfitting during the training of the neural network, early stopping method is being added. Early stopping is a form of regularization used to avoid overfitting when training a learner with an iterative method.

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)

# %% [markdown]
# ### Training The Artificial Neural Network

# %%
NNmodel.fit(x=X_train, y=y_train, epochs=1000, validation_data=(X_test,y_test), callbacks=[early_stop])
# Out:
# Epoch 1/1000
# 25/25 [==============================] - 1s 7ms/step - loss: 0.2671 - val_loss: 0.2212
# Epoch 2/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2018 - val_loss: 0.1707
# Epoch 3/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1545 - val_loss: 0.1263
# Epoch 4/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1111 - val_loss: 0.0880
# Epoch 5/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0784 - val_loss: 0.0663
# Epoch 6/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0599 - val_loss: 0.0577
# Epoch 7/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0546 - val_loss: 0.0543
# Epoch 8/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0483 - val_loss: 0.0528
# Epoch 9/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0500 - val_loss: 0.0520
# Epoch 10/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0465 - val_loss: 0.0516
# Epoch 11/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0478 - val_loss: 0.0512
# Epoch 12/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0476 - val_loss: 0.0507
# Epoch 13/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0459 - val_loss: 0.0500
# Epoch 14/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0466 - val_loss: 0.0492
# Epoch 15/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0481 - val_loss: 0.0485
# Epoch 16/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0448 - val_loss: 0.0477
# Epoch 17/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0437 - val_loss: 0.0470
# Epoch 18/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0438 - val_loss: 0.0465
# Epoch 19/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0423 - val_loss: 0.0460
# Epoch 20/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0426 - val_loss: 0.0453
# Epoch 21/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0420 - val_loss: 0.0447
# Epoch 22/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0416 - val_loss: 0.0439
# Epoch 23/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0409 - val_loss: 0.0433
# Epoch 24/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0407 - val_loss: 0.0423
# Epoch 25/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0388 - val_loss: 0.0414
# Epoch 26/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0358 - val_loss: 0.0403
# Epoch 27/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0380 - val_loss: 0.0389
# Epoch 28/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0348 - val_loss: 0.0375
# Epoch 29/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0362 - val_loss: 0.0357
# Epoch 30/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0340 - val_loss: 0.0339
# Epoch 31/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0312 - val_loss: 0.0320
# Epoch 32/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0273 - val_loss: 0.0304
# Epoch 33/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0275 - val_loss: 0.0282
# Epoch 34/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0255 - val_loss: 0.0262
# Epoch 35/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0245 - val_loss: 0.0241
# Epoch 36/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0215 - val_loss: 0.0220
# Epoch 37/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0199 - val_loss: 0.0195
# Epoch 38/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0176 - val_loss: 0.0165
# Epoch 39/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0149 - val_loss: 0.0133
# Epoch 40/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0114 - val_loss: 0.0106
# Epoch 41/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0086
# Epoch 42/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.0071
# Epoch 43/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0060
# Epoch 44/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 45/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 46/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 47/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 48/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 49/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 50/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0040
# Epoch 51/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 52/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 53/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 54/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 55/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 56/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 57/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 58/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 59/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 60/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 61/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 62/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 63/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 64/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 65/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 66/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 67/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 68/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 69/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 70/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 71/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0029
# Epoch 72/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 73/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 74/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 75/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0028
# Epoch 76/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 77/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 78/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 79/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 80/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 81/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 82/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 83/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 84/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 85/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 86/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 87/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 88/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 89/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 90/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 91/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.001 - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 92/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 93/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 94/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 95/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 96/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 97/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 98/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 99/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 100/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 101/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 102/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 103/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 104/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 105/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 106/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 107/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 108/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 109/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 110/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 111/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 112/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 113/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 114/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 115/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 116/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 117/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 118/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 119/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 120/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 121/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 122/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 123/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 124/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 125/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 126/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 127/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 128/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 129/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 130/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 131/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 132/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.6675e-04 - val_loss: 0.0011
# Epoch 133/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 134/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 135/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.8727e-04 - val_loss: 0.0010
# Epoch 136/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.2789e-04 - val_loss: 9.9052e-04
# Epoch 137/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 9.8046e-04
# Epoch 138/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.0117e-04 - val_loss: 9.5717e-04
# Epoch 139/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.9046e-04 - val_loss: 9.3581e-04
# Epoch 140/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.6572e-04 - val_loss: 9.3255e-04
# Epoch 141/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.3207e-04 - val_loss: 9.2424e-04
# Epoch 142/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.7340e-04 - val_loss: 8.9452e-04
# Epoch 143/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.6478e-04 - val_loss: 9.1126e-04
# Epoch 144/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.7393e-04 - val_loss: 8.8491e-04
# Epoch 145/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.3595e-04 - val_loss: 8.6953e-04
# Epoch 146/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.4648e-04 - val_loss: 8.5085e-04
# Epoch 147/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.9179e-04 - val_loss: 8.4595e-04
# Epoch 148/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.5389e-04 - val_loss: 8.5718e-04
# Epoch 149/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.8925e-04 - val_loss: 8.2078e-04
# Epoch 150/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.7406e-04 - val_loss: 8.5791e-04
# Epoch 151/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.7265e-04 - val_loss: 7.9818e-04
# Epoch 152/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.8941e-04 - val_loss: 7.9063e-04
# Epoch 153/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.0479e-04 - val_loss: 8.1792e-04
# Epoch 154/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.3577e-04 - val_loss: 7.7075e-04
# Epoch 155/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.2136e-04 - val_loss: 7.5760e-04
# Epoch 156/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.8549e-04 - val_loss: 7.6518e-04
# Epoch 157/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.2475e-04 - val_loss: 7.5425e-04
# Epoch 158/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.9451e-04 - val_loss: 7.4136e-04
# Epoch 159/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.6494e-04 - val_loss: 7.2195e-04
# Epoch 160/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.4994e-04 - val_loss: 7.2846e-04
# Epoch 161/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.6406e-04 - val_loss: 7.1298e-04
# Epoch 162/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.8115e-04 - val_loss: 7.0217e-04
# Epoch 163/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.3706e-04 - val_loss: 6.9795e-04
# Epoch 164/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.6764e-04 - val_loss: 6.8228e-04
# Epoch 165/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.4723e-04 - val_loss: 6.7109e-04
# Epoch 166/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.7099e-04 - val_loss: 6.6733e-04
# Epoch 167/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.7112e-04 - val_loss: 6.5837e-04
# Epoch 168/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.6116e-04 - val_loss: 6.5231e-04
# Epoch 169/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.1243e-04 - val_loss: 6.5444e-04
# Epoch 170/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.8635e-04 - val_loss: 6.3516e-04
# Epoch 171/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.8611e-04 - val_loss: 6.2596e-04
# Epoch 172/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 5.7912e-04 - val_loss: 6.2011e-04
# Epoch 173/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.7967e-04 - val_loss: 6.1287e-04
# Epoch 174/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.0680e-04 - val_loss: 6.1184e-04
# Epoch 175/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.0270e-04 - val_loss: 6.3531e-04
# Epoch 176/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.7306e-04 - val_loss: 6.0443e-04
# Epoch 177/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4026e-04 - val_loss: 6.1052e-04
# Epoch 178/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.6249e-04 - val_loss: 5.8842e-04
# Epoch 179/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.3077e-04 - val_loss: 5.7271e-04
# Epoch 180/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.7095e-04 - val_loss: 5.6874e-04
# Epoch 181/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4731e-04 - val_loss: 5.6708e-04
# Epoch 182/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.3659e-04 - val_loss: 5.8466e-04
# Epoch 183/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4817e-04 - val_loss: 5.5541e-04
# Epoch 184/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.9803e-04 - val_loss: 5.5524e-04
# Epoch 185/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.1085e-04 - val_loss: 5.4510e-04
# Epoch 186/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.1933e-04 - val_loss: 5.3617e-04
# Epoch 187/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0512e-04 - val_loss: 5.4258e-04
# Epoch 188/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0306e-04 - val_loss: 5.2530e-04
# Epoch 189/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.1212e-04 - val_loss: 5.2762e-04
# Epoch 190/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.6527e-04 - val_loss: 5.1695e-04
# Epoch 191/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.3810e-04 - val_loss: 5.1400e-04
# Epoch 192/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.7870e-04 - val_loss: 5.0477e-04
# Epoch 193/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.6737e-04 - val_loss: 4.9600e-04
# Epoch 194/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.6195e-04 - val_loss: 4.9117e-04
# Epoch 195/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.3551e-04 - val_loss: 4.8700e-04
# Epoch 196/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.5139e-04 - val_loss: 4.7988e-04
# Epoch 197/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.2920e-04 - val_loss: 4.7448e-04
# Epoch 198/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.6393e-04 - val_loss: 4.7046e-04
# Epoch 199/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.3083e-04 - val_loss: 4.7725e-04
# Epoch 200/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.4745e-04 - val_loss: 4.6589e-04
# Epoch 201/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.7796e-04 - val_loss: 4.5372e-04
# Epoch 202/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.0666e-04 - val_loss: 4.5057e-04
# Epoch 203/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.7318e-04 - val_loss: 4.6153e-04
# Epoch 204/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.6238e-04 - val_loss: 4.4299e-04
# Epoch 205/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.8989e-04 - val_loss: 4.4084e-04
# Epoch 206/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.4573e-04 - val_loss: 4.4226e-04
# Epoch 207/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 4.4503e-04 - val_loss: 4.4538e-04
# Epoch 208/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.8839e-04 - val_loss: 4.2962e-04
# Epoch 209/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.0814e-04 - val_loss: 4.2458e-04
# Epoch 210/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.8007e-04 - val_loss: 4.2094e-04
# Epoch 211/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.0993e-04 - val_loss: 4.2863e-04
# Epoch 212/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 3.7757e-04 - val_loss: 4.1067e-04
# Epoch 213/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.7031e-04 - val_loss: 4.0701e-04
# Epoch 214/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.9085e-04 - val_loss: 4.0061e-04
# Epoch 215/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.6616e-04 - val_loss: 4.0039e-04
# Epoch 216/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.9394e-04 - val_loss: 3.9637e-04
# Epoch 217/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.5785e-04 - val_loss: 3.9540e-04
# Epoch 218/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.2484e-04 - val_loss: 3.9064e-04
# Epoch 219/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.4978e-04 - val_loss: 3.8225e-04
# Epoch 220/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.4386e-04 - val_loss: 3.7994e-04
# Epoch 221/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.5361e-04 - val_loss: 3.8143e-04
# Epoch 222/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.4296e-04 - val_loss: 3.6923e-04
# Epoch 223/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.2644e-04 - val_loss: 3.7767e-04
# Epoch 224/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 3.8313e-04 - val_loss: 3.6724e-04
# Epoch 225/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.4842e-04 - val_loss: 3.6170e-04
# Epoch 226/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.4143e-04 - val_loss: 3.5636e-04
# Epoch 227/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.1589e-04 - val_loss: 3.5191e-04
# Epoch 228/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.0597e-04 - val_loss: 3.6300e-04
# Epoch 229/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.2118e-04 - val_loss: 3.4781e-04
# Epoch 230/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.4323e-04 - val_loss: 3.4157e-04
# Epoch 231/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.3294e-04 - val_loss: 3.4132e-04
# Epoch 232/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.1092e-04 - val_loss: 3.8754e-04
# Epoch 233/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.4167e-04 - val_loss: 3.3234e-04
# Epoch 234/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.1669e-04 - val_loss: 3.2746e-04
# Epoch 235/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.0068e-04 - val_loss: 3.2230e-04
# Epoch 236/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.7883e-04 - val_loss: 3.2088e-04
# Epoch 237/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 3.2732e-04 - val_loss: 3.1923e-04
# Epoch 238/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.1431e-04 - val_loss: 3.2145e-04
# Epoch 239/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.9144e-04 - val_loss: 3.1000e-04
# Epoch 240/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.9966e-04 - val_loss: 3.1048e-04
# Epoch 241/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.9268e-04 - val_loss: 3.0451e-04
# Epoch 242/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.8411e-04 - val_loss: 3.0978e-04
# Epoch 243/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.8585e-04 - val_loss: 3.0119e-04
# Epoch 244/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.1157e-04 - val_loss: 3.0199e-04
# Epoch 245/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.2667e-04 - val_loss: 2.9870e-04
# Epoch 246/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.6209e-04 - val_loss: 3.0866e-04
# Epoch 247/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.7003e-04 - val_loss: 3.0437e-04
# Epoch 248/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.9916e-04 - val_loss: 3.0068e-04
# Epoch 249/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.8006e-04 - val_loss: 2.7713e-04
# Epoch 250/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.5669e-04 - val_loss: 2.8085e-04
# Epoch 251/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.8672e-04 - val_loss: 2.7518e-04
# Epoch 252/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.4398e-04 - val_loss: 2.7298e-04
# Epoch 253/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.4999e-04 - val_loss: 2.6634e-04
# Epoch 254/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.5529e-04 - val_loss: 2.7077e-04
# Epoch 255/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.7006e-04 - val_loss: 2.8444e-04
# Epoch 256/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.8713e-04 - val_loss: 2.5738e-04
# Epoch 257/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.4211e-04 - val_loss: 2.5569e-04
# Epoch 258/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.5080e-04 - val_loss: 2.5888e-04
# Epoch 259/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.4129e-04 - val_loss: 2.7682e-04
# Epoch 260/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.5674e-04 - val_loss: 2.6114e-04
# Epoch 261/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.3947e-04 - val_loss: 2.4948e-04
# Epoch 262/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.3253e-04 - val_loss: 2.4475e-04
# Epoch 263/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.6700e-04 - val_loss: 2.3963e-04
# Epoch 264/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.5266e-04 - val_loss: 2.4862e-04
# Epoch 265/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2903e-04 - val_loss: 2.4197e-04
# Epoch 266/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.4260e-04 - val_loss: 2.3305e-04
# Epoch 267/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.3552e-04 - val_loss: 2.4129e-04
# Epoch 268/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.3856e-04 - val_loss: 2.3296e-04
# Epoch 269/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1830e-04 - val_loss: 2.2878e-04
# Epoch 270/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.4520e-04 - val_loss: 2.3471e-04
# Epoch 271/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1837e-04 - val_loss: 2.2397e-04
# Epoch 272/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9337e-04 - val_loss: 2.2688e-04
# Epoch 273/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2942e-04 - val_loss: 2.1733e-04
# Epoch 274/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1880e-04 - val_loss: 2.1829e-04
# Epoch 275/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2072e-04 - val_loss: 2.1546e-04
# Epoch 276/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9661e-04 - val_loss: 2.1461e-04
# Epoch 277/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9887e-04 - val_loss: 2.1322e-04
# Epoch 278/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9053e-04 - val_loss: 2.1215e-04
# Epoch 279/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8293e-04 - val_loss: 2.0249e-04
# Epoch 280/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9877e-04 - val_loss: 2.2271e-04
# Epoch 281/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.4221e-04 - val_loss: 1.9900e-04
# Epoch 282/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0922e-04 - val_loss: 1.9952e-04
# Epoch 283/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7847e-04 - val_loss: 2.0990e-04
# Epoch 284/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0075e-04 - val_loss: 1.9143e-04
# Epoch 285/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8748e-04 - val_loss: 1.8680e-04
# Epoch 286/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0123e-04 - val_loss: 1.8790e-04
# Epoch 287/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8477e-04 - val_loss: 1.8349e-04
# Epoch 288/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5651e-04 - val_loss: 1.8471e-04
# Epoch 289/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6905e-04 - val_loss: 1.8073e-04
# Epoch 290/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5978e-04 - val_loss: 1.8141e-04
# Epoch 291/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8024e-04 - val_loss: 1.7968e-04
# Epoch 292/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4431e-04 - val_loss: 1.8339e-04
# Epoch 293/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8712e-04 - val_loss: 1.8100e-04
# Epoch 294/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6637e-04 - val_loss: 1.7095e-04
# Epoch 295/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6533e-04 - val_loss: 1.7128e-04
# Epoch 296/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8420e-04 - val_loss: 1.6924e-04
# Epoch 297/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7721e-04 - val_loss: 1.7064e-04
# Epoch 298/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6483e-04 - val_loss: 1.6809e-04
# Epoch 299/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7741e-04 - val_loss: 1.6835e-04
# Epoch 300/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6639e-04 - val_loss: 1.8077e-04
# Epoch 301/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5861e-04 - val_loss: 1.6237e-04
# Epoch 302/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7172e-04 - val_loss: 1.6449e-04
# Epoch 303/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5419e-04 - val_loss: 1.7596e-04
# Epoch 304/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6288e-04 - val_loss: 1.6449e-04
# Epoch 305/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6768e-04 - val_loss: 1.5925e-04
# Epoch 306/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8689e-04 - val_loss: 1.6462e-04
# Epoch 307/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6220e-04 - val_loss: 1.6030e-04
# Epoch 308/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5216e-04 - val_loss: 1.5807e-04
# Epoch 309/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5279e-04 - val_loss: 1.6093e-04
# Epoch 310/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6487e-04 - val_loss: 1.6808e-04
# Epoch 311/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7220e-04 - val_loss: 1.5496e-04
# Epoch 312/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3941e-04 - val_loss: 1.5981e-04
# Epoch 313/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5243e-04 - val_loss: 1.5116e-04
# Epoch 314/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5236e-04 - val_loss: 1.6125e-04
# Epoch 315/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4574e-04 - val_loss: 1.4807e-04
# Epoch 316/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4077e-04 - val_loss: 1.4869e-04
# Epoch 317/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4385e-04 - val_loss: 1.6396e-04
# Epoch 318/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5515e-04 - val_loss: 1.5191e-04
# Epoch 319/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4393e-04 - val_loss: 1.5560e-04
# Epoch 320/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5103e-04 - val_loss: 1.4616e-04
# Epoch 321/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4917e-04 - val_loss: 1.4604e-04
# Epoch 322/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3601e-04 - val_loss: 1.7024e-04
# Epoch 323/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4963e-04 - val_loss: 1.4373e-04
# Epoch 324/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4089e-04 - val_loss: 1.4947e-04
# Epoch 325/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3178e-04 - val_loss: 1.5772e-04
# Epoch 326/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3138e-04 - val_loss: 1.4058e-04
# Epoch 327/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4377e-04 - val_loss: 1.4002e-04
# Epoch 328/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.4577e-04 - val_loss: 1.4459e-04
# Epoch 329/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3584e-04 - val_loss: 1.4063e-04
# Epoch 330/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4488e-04 - val_loss: 1.3781e-04
# Epoch 331/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3803e-04 - val_loss: 1.5958e-04
# Epoch 332/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4682e-04 - val_loss: 1.3744e-04
# Epoch 333/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2562e-04 - val_loss: 1.4024e-04
# Epoch 334/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2846e-04 - val_loss: 1.3634e-04
# Epoch 335/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3642e-04 - val_loss: 1.3955e-04
# Epoch 336/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4722e-04 - val_loss: 1.3582e-04
# Epoch 337/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3553e-04 - val_loss: 1.3976e-04
# Epoch 338/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1452e-04 - val_loss: 1.3402e-04
# Epoch 339/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3413e-04 - val_loss: 1.5012e-04
# Epoch 340/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2466e-04 - val_loss: 1.3415e-04
# Epoch 341/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3063e-04 - val_loss: 1.3035e-04
# Epoch 342/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3294e-04 - val_loss: 1.2971e-04
# Epoch 343/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2046e-04 - val_loss: 1.3182e-04
# Epoch 344/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2679e-04 - val_loss: 1.3396e-04
# Epoch 345/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4633e-04 - val_loss: 1.2878e-04
# Epoch 346/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3273e-04 - val_loss: 1.3821e-04
# Epoch 347/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5454e-04 - val_loss: 1.3344e-04
# Epoch 348/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3147e-04 - val_loss: 1.3885e-04
# Epoch 349/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2021e-04 - val_loss: 1.2993e-04
# Epoch 350/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1861e-04 - val_loss: 1.3296e-04
# Epoch 351/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3136e-04 - val_loss: 1.4760e-04
# Epoch 352/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2269e-04 - val_loss: 1.4404e-04
# Epoch 353/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3078e-04 - val_loss: 1.3229e-04
# Epoch 354/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2503e-04 - val_loss: 1.2379e-04
# Epoch 355/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1311e-04 - val_loss: 1.4080e-04
# Epoch 356/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2308e-04 - val_loss: 1.4109e-04
# Epoch 357/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4696e-04 - val_loss: 1.2764e-04
# Epoch 358/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3719e-04 - val_loss: 1.2911e-04
# Epoch 359/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1667e-04 - val_loss: 1.3011e-04
# Epoch 360/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2860e-04 - val_loss: 1.2640e-04
# Epoch 361/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2116e-04 - val_loss: 1.2986e-04
# Epoch 362/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2581e-04 - val_loss: 1.2019e-04
# Epoch 363/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2513e-04 - val_loss: 1.3227e-04
# Epoch 364/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2243e-04 - val_loss: 1.1944e-04
# Epoch 365/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1441e-04 - val_loss: 1.2250e-04
# Epoch 366/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1444e-04 - val_loss: 1.4123e-04
# Epoch 367/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2871e-04 - val_loss: 1.2242e-04
# Epoch 368/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1515e-04 - val_loss: 1.2284e-04
# Epoch 369/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2589e-04 - val_loss: 1.1885e-04
# Epoch 370/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2593e-04 - val_loss: 1.2076e-04
# Epoch 371/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0947e-04 - val_loss: 1.2144e-04
# Epoch 372/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1350e-04 - val_loss: 1.2588e-04
# Epoch 373/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1213e-04 - val_loss: 1.2069e-04
# Epoch 374/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1275e-04 - val_loss: 1.1799e-04
# Epoch 375/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1088e-04 - val_loss: 1.1989e-04
# Epoch 376/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1084e-04 - val_loss: 1.1764e-04
# Epoch 377/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2036e-04 - val_loss: 1.2820e-04
# Epoch 378/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1123e-04 - val_loss: 1.1808e-04
# Epoch 379/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1106e-04 - val_loss: 1.2036e-04
# Epoch 380/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1029e-04 - val_loss: 1.1595e-04
# Epoch 381/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0411e-04 - val_loss: 1.2031e-04
# Epoch 382/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2272e-04 - val_loss: 1.2290e-04
# Epoch 383/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1295e-04 - val_loss: 1.1697e-04
# Epoch 384/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1352e-04 - val_loss: 1.3146e-04
# Epoch 385/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1391e-04 - val_loss: 1.1561e-04
# Epoch 386/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0746e-04 - val_loss: 1.2665e-04
# Epoch 387/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1664e-04 - val_loss: 1.2943e-04
# Epoch 388/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2227e-04 - val_loss: 1.1660e-04
# Epoch 389/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2901e-04 - val_loss: 1.1631e-04
# Epoch 390/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2737e-04 - val_loss: 1.1213e-04
# Epoch 391/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0794e-04 - val_loss: 1.1082e-04
# Epoch 392/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2171e-04 - val_loss: 1.1481e-04
# Epoch 393/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2245e-04 - val_loss: 1.2121e-04
# Epoch 394/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1499e-04 - val_loss: 1.0828e-04
# Epoch 395/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0766e-04 - val_loss: 1.1061e-04
# Epoch 396/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1815e-04 - val_loss: 1.1254e-04
# Epoch 397/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0654e-04 - val_loss: 1.2384e-04
# Epoch 398/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0409e-04 - val_loss: 1.0889e-04
# Epoch 399/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0078e-04 - val_loss: 1.2028e-04
# Epoch 400/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0833e-04 - val_loss: 1.0751e-04
# Epoch 401/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0927e-04 - val_loss: 1.1159e-04
# Epoch 402/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1291e-04 - val_loss: 1.1226e-04
# Epoch 403/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1437e-04 - val_loss: 1.1384e-04
# Epoch 404/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0517e-04 - val_loss: 1.0523e-04
# Epoch 405/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0014e-04 - val_loss: 1.1901e-04
# Epoch 406/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2235e-04 - val_loss: 1.0788e-04
# Epoch 407/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1002e-04 - val_loss: 1.0639e-04
# Epoch 408/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.6201e-05 - val_loss: 1.1386e-04
# Epoch 409/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0799e-04 - val_loss: 1.0800e-04
# Epoch 410/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0825e-04 - val_loss: 1.0826e-04
# Epoch 411/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.7057e-05 - val_loss: 1.1208e-04
# Epoch 412/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.7811e-05 - val_loss: 1.1849e-04
# Epoch 413/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0536e-04 - val_loss: 1.1050e-04
# Epoch 414/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0626e-04 - val_loss: 1.2125e-04
# Epoch 415/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0391e-04 - val_loss: 1.0454e-04
# Epoch 416/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 9.4592e-05 - val_loss: 1.1231e-04
# Epoch 417/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0681e-04 - val_loss: 1.1112e-04
# Epoch 418/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0156e-04 - val_loss: 1.1572e-04
# Epoch 419/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1456e-04 - val_loss: 1.1067e-04
# Epoch 420/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1115e-04 - val_loss: 1.0840e-04
# Epoch 421/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.6816e-05 - val_loss: 1.0617e-04
# Epoch 422/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1169e-04 - val_loss: 1.0953e-04
# Epoch 423/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0943e-04 - val_loss: 1.0672e-04
# Epoch 424/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0883e-04 - val_loss: 1.0969e-04
# Epoch 425/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2390e-04 - val_loss: 1.0343e-04
# Epoch 426/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.8872e-05 - val_loss: 1.0349e-04
# Epoch 427/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.3996e-05 - val_loss: 1.2300e-04
# Epoch 428/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0276e-04 - val_loss: 1.0730e-04
# Epoch 429/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0023e-04 - val_loss: 1.0408e-04
# Epoch 430/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.3164e-05 - val_loss: 1.0673e-04
# Epoch 431/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0951e-04 - val_loss: 1.0550e-04
# Epoch 432/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0494e-04 - val_loss: 1.0302e-04
# Epoch 433/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.8282e-05 - val_loss: 1.0529e-04
# Epoch 434/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0381e-04 - val_loss: 1.0195e-04
# Epoch 435/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.5862e-05 - val_loss: 1.0012e-04
# Epoch 436/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.0246e-05 - val_loss: 9.8673e-05
# Epoch 437/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.6066e-05 - val_loss: 1.1213e-04
# Epoch 438/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1462e-04 - val_loss: 1.1351e-04
# Epoch 439/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.3416e-05 - val_loss: 1.0138e-04
# Epoch 440/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.6879e-05 - val_loss: 1.1207e-04
# Epoch 441/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0385e-04 - val_loss: 1.0527e-04
# Epoch 442/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.8030e-05 - val_loss: 1.0886e-04
# Epoch 443/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.5830e-05 - val_loss: 1.1163e-04
# Epoch 444/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.6952e-05 - val_loss: 1.0183e-04
# Epoch 445/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.5998e-05 - val_loss: 9.7645e-05
# Epoch 446/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.8233e-05 - val_loss: 1.1066e-04
# Epoch 447/1000
# ...
# Epoch 761/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.9758e-05 - val_loss: 5.2743e-05
# Epoch 762/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0779e-05 - val_loss: 5.8215e-05
# Epoch 763/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.2608e-05 - val_loss: 5.7026e-05
# Epoch 764/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.7070e-05 - val_loss: 5.6508e-05
# Epoch 765/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.1386e-05 - val_loss: 5.4191e-05
# Epoch 766/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.3600e-05 - val_loss: 5.3685e-05
# Epoch 767/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.2446e-05 - val_loss: 5.2478e-05
# Epoch 768/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.6802e-05 - val_loss: 5.4288e-05
# Epoch 769/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0628e-05 - val_loss: 5.8600e-05
# Epoch 770/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.8332e-05 - val_loss: 7.6501e-05
# Epoch 771/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.8978e-05 - val_loss: 5.5964e-05
# Epoch 772/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4568e-05 - val_loss: 6.1342e-05
# Epoch 773/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.3217e-05 - val_loss: 6.5349e-05
# Epoch 774/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.5111e-05 - val_loss: 6.4509e-05
# Epoch 775/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.3180e-05 - val_loss: 5.0895e-05
# Epoch 776/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.2785e-05 - val_loss: 5.6811e-05
# Epoch 777/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0113e-05 - val_loss: 5.3193e-05
# Epoch 778/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.3089e-05 - val_loss: 5.1426e-05
# Epoch 779/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.1776e-05 - val_loss: 5.9611e-05
# Epoch 780/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4522e-05 - val_loss: 5.2929e-05
# Epoch 781/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4679e-05 - val_loss: 5.7319e-05
# Epoch 782/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.8490e-05 - val_loss: 5.9613e-05
# Epoch 783/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.8351e-05 - val_loss: 5.1581e-05
# Epoch 784/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.9378e-05 - val_loss: 5.2103e-05
# Epoch 785/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.7010e-05 - val_loss: 6.2967e-05
# Epoch 786/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4473e-05 - val_loss: 5.6033e-05
# Epoch 787/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.7330e-05 - val_loss: 4.9871e-05
# Epoch 788/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.1684e-05 - val_loss: 5.3406e-05
# Epoch 789/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.6066e-05 - val_loss: 5.7411e-05
# Epoch 790/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.6220e-05 - val_loss: 5.1488e-05
# Epoch 791/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.5865e-05 - val_loss: 6.3961e-05
# Epoch 792/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4500e-05 - val_loss: 6.6848e-05
# Epoch 793/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.5414e-05 - val_loss: 5.8598e-05
# Epoch 794/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.4298e-05 - val_loss: 6.4461e-05
# Epoch 795/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.6174e-05 - val_loss: 5.7457e-05
# Epoch 796/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.8558e-05 - val_loss: 5.8988e-05
# Epoch 797/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.1471e-05 - val_loss: 5.5709e-05
# Epoch 798/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0363e-05 - val_loss: 7.4948e-05
# Epoch 799/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.1687e-05 - val_loss: 5.7026e-05
# Epoch 800/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.9856e-05 - val_loss: 5.1699e-05
# Epoch 801/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.5979e-05 - val_loss: 5.2166e-05
# Epoch 802/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.8720e-05 - val_loss: 6.0137e-05
# Epoch 803/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 5.2480e-05 - val_loss: 5.1481e-05
# Epoch 804/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0550e-05 - val_loss: 5.2102e-05
# Epoch 805/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.4581e-05 - val_loss: 6.7568e-05
# Epoch 806/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.8352e-05 - val_loss: 6.2314e-05
# Epoch 807/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.7807e-05 - val_loss: 5.1181e-05
# Epoch 808/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.7174e-05 - val_loss: 4.9278e-05
# Epoch 809/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.9813e-05 - val_loss: 5.1013e-05
# Epoch 810/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.1176e-05 - val_loss: 4.9066e-05
# Epoch 811/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0756e-05 - val_loss: 5.0698e-05
# Epoch 812/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0182e-05 - val_loss: 4.9386e-05
# Epoch 813/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0537e-05 - val_loss: 5.2413e-05
# Epoch 814/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4527e-05 - val_loss: 6.5981e-05
# Epoch 815/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4486e-05 - val_loss: 6.1717e-05
# Epoch 816/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.8076e-05 - val_loss: 4.9528e-05
# Epoch 817/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.7366e-05 - val_loss: 5.5341e-05
# Epoch 818/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.1653e-05 - val_loss: 5.7687e-05
# Epoch 819/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.1252e-05 - val_loss: 6.0459e-05
# Epoch 820/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0468e-05 - val_loss: 5.7288e-05
# Epoch 821/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4194e-05 - val_loss: 7.3384e-05
# Epoch 822/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.9183e-05 - val_loss: 5.4736e-05
# Epoch 823/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 5.1453e-05 - val_loss: 5.0210e-05
# Epoch 824/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.9843e-05 - val_loss: 5.7056e-05
# Epoch 825/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0966e-05 - val_loss: 4.8120e-05
# Epoch 826/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.5577e-05 - val_loss: 5.6855e-05
# Epoch 827/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.8795e-05 - val_loss: 5.6960e-05
# Epoch 828/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.9552e-05 - val_loss: 6.6102e-05
# Epoch 829/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.8538e-05 - val_loss: 5.3188e-05
# Epoch 830/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0434e-05 - val_loss: 4.9857e-05
# Epoch 831/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.5413e-05 - val_loss: 4.8632e-05
# Epoch 832/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.4710e-05 - val_loss: 4.9747e-05
# Epoch 833/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.4674e-05 - val_loss: 5.9521e-05
# Epoch 834/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.3535e-05 - val_loss: 5.1206e-05
# Epoch 835/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.9121e-05 - val_loss: 4.6895e-05
# Epoch 836/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.2164e-05 - val_loss: 5.4938e-05
# Epoch 837/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0190e-05 - val_loss: 5.0786e-05
# Epoch 838/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.2350e-05 - val_loss: 5.9593e-05
# Epoch 839/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.5839e-05 - val_loss: 4.9172e-05
# Epoch 840/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.3638e-05 - val_loss: 4.9236e-05
# Epoch 841/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.9773e-05 - val_loss: 4.9391e-05
# Epoch 842/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.6384e-05 - val_loss: 4.7939e-05
# Epoch 843/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.6610e-05 - val_loss: 4.8654e-05
# Epoch 844/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.3702e-05 - val_loss: 5.0025e-05
# Epoch 845/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.1843e-05 - val_loss: 5.3423e-05
# Epoch 846/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.9843e-05 - val_loss: 5.7303e-05
# Epoch 847/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.3451e-05 - val_loss: 1.0873e-04
# Epoch 848/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.6356e-05 - val_loss: 5.3622e-05
# Epoch 849/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.6747e-05 - val_loss: 4.9715e-05
# Epoch 850/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.5766e-05 - val_loss: 5.6449e-05
# Epoch 851/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.3256e-05 - val_loss: 4.7600e-05
# Epoch 852/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.9835e-05 - val_loss: 5.3168e-05
# Epoch 853/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.7334e-05 - val_loss: 5.1594e-05
# Epoch 854/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.8773e-05 - val_loss: 4.7529e-05
# Epoch 855/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.4001e-05 - val_loss: 4.6739e-05
# Epoch 856/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.5448e-05 - val_loss: 9.3171e-05
# Epoch 857/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.9661e-05 - val_loss: 6.1332e-05
# Epoch 858/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.5180e-05 - val_loss: 5.7257e-05
# Epoch 859/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.7140e-05 - val_loss: 4.9416e-05
# Epoch 860/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.7402e-05 - val_loss: 4.8133e-05
# Epoch 861/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.6068e-05 - val_loss: 6.2223e-05
# Epoch 862/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.8673e-05 - val_loss: 5.3011e-05
# Epoch 863/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.1675e-05 - val_loss: 4.8167e-05
# Epoch 864/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.2104e-05 - val_loss: 4.8955e-05
# Epoch 865/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.6603e-05 - val_loss: 4.8719e-05
# Epoch 866/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.1308e-05 - val_loss: 5.5859e-05
# Epoch 867/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.8727e-05 - val_loss: 5.2000e-05
# Epoch 868/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4113e-05 - val_loss: 4.9293e-05
# Epoch 869/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.1435e-05 - val_loss: 5.1073e-05
# Epoch 870/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.2960e-05 - val_loss: 4.7344e-05
# Epoch 871/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.1298e-05 - val_loss: 5.3091e-05
# Epoch 872/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.2030e-05 - val_loss: 4.9686e-05
# Epoch 873/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.3815e-05 - val_loss: 5.0741e-05
# Epoch 874/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4204e-05 - val_loss: 4.9540e-05
# Epoch 875/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.2462e-05 - val_loss: 6.2892e-05
# Epoch 876/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.6996e-05 - val_loss: 5.0909e-05
# Epoch 877/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0794e-05 - val_loss: 5.5231e-05
# Epoch 878/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.6574e-05 - val_loss: 5.2801e-05
# Epoch 879/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.2875e-05 - val_loss: 5.4161e-05
# Epoch 880/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.1992e-05 - val_loss: 4.8425e-05
# Epoch 881/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.9877e-05 - val_loss: 5.5114e-05
# Epoch 882/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0049e-05 - val_loss: 6.2760e-05
# Epoch 883/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.7553e-05 - val_loss: 5.1303e-05
# Epoch 884/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0428e-05 - val_loss: 4.7827e-05
# Epoch 885/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.7300e-05 - val_loss: 4.7494e-05
# Epoch 886/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.3557e-05 - val_loss: 5.5212e-05
# Epoch 887/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.8111e-05 - val_loss: 4.9693e-05
# Epoch 888/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.6365e-05 - val_loss: 4.7009e-05
# Epoch 889/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.8066e-05 - val_loss: 4.8261e-05
# Epoch 890/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.9272e-05 - val_loss: 4.8841e-05
# Epoch 891/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.7034e-05 - val_loss: 5.1073e-05
# Epoch 892/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.4991e-05 - val_loss: 5.1760e-05
# Epoch 893/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.7802e-05 - val_loss: 5.1216e-05
# Epoch 894/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.3035e-05 - val_loss: 5.0239e-05
# Epoch 895/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.4954e-05 - val_loss: 5.9014e-05
# Epoch 896/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.7234e-05 - val_loss: 4.9389e-05
# Epoch 897/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.3715e-05 - val_loss: 4.6843e-05
# Epoch 898/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.3225e-05 - val_loss: 6.1313e-05
# Epoch 899/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.5893e-05 - val_loss: 5.2533e-05
# Epoch 900/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.3317e-05 - val_loss: 5.2383e-05
# Epoch 901/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.7906e-05 - val_loss: 6.1289e-05
# Epoch 902/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.6716e-05 - val_loss: 5.5842e-05
# Epoch 903/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.9941e-05 - val_loss: 5.1058e-05
# Epoch 904/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.7586e-05 - val_loss: 5.1777e-05
# Epoch 905/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.3252e-05 - val_loss: 5.0057e-05
# Epoch 00905: early stopping

# %% [markdown]
# ### Plotting The Losses During Training

# %%
losses = pd.DataFrame(NNmodel.history.history)
losses[['loss', 'val_loss']].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Predicting On The Test Dataset

# %%
predictions = NNmodel.predict(X_test)

# %%
predictions = scalery.inverse_transform(predictions)
y_test = scalery.inverse_transform(y_test)

# %% [markdown]
# ### Mean Squared Error and Mean Absolute Error of the Prediction Results

# %%
mse_cl = mean_squared_error(y_test[:,0], predictions[:,0])
print(f"Mean Squared Error for Cl: {mse_cl}")
mae_cl = np.sum(np.absolute(y_test[:,0]- predictions[:,0]))/len(y_test)
print(f"Mean Absolute Error for Cl: {mae_cl}\n")
mse_cd = mean_squared_error(y_test[:,1], predictions[:,1])
print(f"Mean Squared Error for Cd: {mse_cd}")
mae_cd = np.sum(np.absolute(y_test[:,1]- predictions[:,1]))/len(y_test)
print(f"Mean Absolute Error for Cd: {mae_cd}\n")
mse_cp = mean_squared_error(y_test[:,2], predictions[:,2])
print(f"Mean Squared Error for Cp: {mse_cp}")
mae_cp = np.sum(np.absolute(y_test[:,2]- predictions[:,2]))/len(y_test)
print(f"Mean Absolute Error for Cp: {mae_cp}\n")
# Out:
# Mean Squared Error for Cl: 6.611430219613798e-07
# Mean Absolute Error for Cl: 0.0006385512363591131
#
# Mean Squared Error for Cd: 4.345763845145812e-09
# Mean Absolute Error for Cd: 4.820845700754328e-05
#
# Mean Squared Error for Cp: 4.98942915549643e-05
# Mean Absolute Error for Cp: 0.005079430650239136

# %% [markdown]
# ### Predictions vs Ground Truth Plots

# %%
###############################Cl
# Creating figure Cl
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], predictions[:,0], color = "black", alpha=1, label='Predictions', marker='x')
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], y_test[:,0], color = "blue", alpha=0.6, label='Ground Truth')
plt.title("Cl Prediction vs Ground Truth")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,0], predictions[:,0], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,0], y_test[:,0], color = "blue", alpha=0.6, label='Ground Truth')
plt.xlabel('Mach Number')
plt.ylabel('Cl')
plt.title('Cl vs Mach Number')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,1], predictions[:,0], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,1], y_test[:,0], color = "blue", alpha=0.6, label='Ground Truth')
plt.xlabel('AoA')
plt.ylabel('Cl')
plt.title('Cl vs AoA')
plt.legend()
plt.show()

##############################Cd
# Creating figure Cd
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], predictions[:,1], color = "black", alpha=1, label='Predictions', marker='x')
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], y_test[:,1], color = "red", alpha=0.6, label='Ground Truth')
plt.title("Cd Prediction vs Ground Truth")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,0], predictions[:,1], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,0], y_test[:,1], color = "red", alpha=0.6, label='Ground Truth')
plt.xlabel('Mach Number')
plt.ylabel('Cd')
plt.title('Cd vs Mach Number')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,1], predictions[:,1], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,1], y_test[:,1], color = "red", alpha=0.6, label='Ground Truth')
plt.xlabel('AoA')
plt.ylabel('Cd')
plt.title('Cd vs AoA')
plt.legend()
plt.show()

##############################Cp
# Creating figure Cp
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], predictions[:,2], color = "black", alpha=1, label='Predictions', marker='x')
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], y_test[:,2], color = "g", alpha=0.6, label='Ground Truth')
plt.title("Cp Prediction vs Ground Truth")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,0], predictions[:,2], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,0], y_test[:,2], color = "green", alpha=0.6, label='Ground Truth')
plt.xlabel('Mach Number')
plt.ylabel('Cd')
plt.title('Cd vs Mach Number')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,1], predictions[:,2], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,1], y_test[:,2], color = "green", alpha=0.6, label='Ground Truth')
plt.xlabel('AoA')
plt.ylabel('Cd')
plt.title('Cd vs AoA')
plt.legend()
plt.show()

# %% [markdown]
# ### Sampling Predictions

# %%
sample_number = 6
#alldata=len(predictions)
print("[Cl Cd Cp]")
for i in range (sample_number):
    print(f"Sample Data {i+1}: {y_test[i]}")
    print(f"Prediction {i+1}: {predictions[i]}")
    error = np.abs(y_test[i]-predictions[i])
    print(f"error: {error}\n--------------------------------------------------")
# Out:
# [Cl Cd Cp]
# Sample Data 1: [ 0.683542  0.011203 -0.686882]
# Prediction 1: [ 0.68279195  0.01121695 -0.68678844]
# error: [7.50051682e-04 1.39450149e-05 9.35602493e-05]
# --------------------------------------------------
# Sample Data 2: [ 0.73528   0.013844 -1.152869]
# Prediction 2: [ 0.73481023  0.01378462 -1.1556052 ]
# error: [4.69766884e-04 5.93800204e-05 2.73619695e-03]
# --------------------------------------------------
# Sample Data 3: [ 0.675539  0.01153  -0.624721]
# Prediction 3: [ 0.6745767   0.01149793 -0.62565106]
# error: [9.62300266e-04 3.20703077e-05 9.30061535e-04]
# --------------------------------------------------
# Sample Data 4: [ 0.652789  0.010931 -0.671232]
# Prediction 4: [ 0.65245205  0.01091899 -0.66836023]
# error: [3.36948360e-04 1.20083598e-05 2.87176669e-03]
# --------------------------------------------------
# Sample Data 5: [ 0.723796  0.014562 -1.201687]
# Prediction 5: [ 0.7233128  0.0145018 -1.1973348]
# error: [4.83204838e-04 6.02020333e-05 4.35223361e-03]
# --------------------------------------------------
# Sample Data 6: [ 0.729271  0.015041 -1.210357]
# Prediction 6: [ 0.7290471   0.01506707 -1.2072691 ]
# error: [2.23880383e-04 2.60716539e-05 3.08792747e-03]
# --------------------------------------------------
