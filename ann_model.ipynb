# %% [markdown]
# # Transonic Airfoil Aerodynamic Coefficients Prediction using Artificial Neural Network

# %% [markdown]
# In this notebook, an artificial neural network model is being modeled to predict the aerodynamic coefficients of an airfoil that flies at a nominal condition of __Mach Number M = 0.729__ where the data of varying M and __angle of attack α__ results in various __lift coefficient Cl__, __drag coefficient Cd__ and the pressure coefficient at the center of the upper surface of the airfoil __Cp__ using _Tensorflow and Keras_.
#
# The data were taken from the following reference: Pramudita Satria Palar, Lavi Rizki Zuhal, and Koji Shimoyama."Gaussian Process Surrogate Model with Composite Kernel Learning for Engineering Design." _AIAA Journal_ 58, no. 4 (2020):1864-1880.
#
# _Notebook made to explore simple Artificial Neural Network, Rafael S_

# %% [markdown]
# ### Importing required packages

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Importing Dataset

# %%
df = pd.read_csv('transonic_airfoil_data_set.csv').drop(columns = 'No')

# %%
df
# Out:
#             M       AoA        Cl        Cd        Cp
# 0    0.727928  2.449037  0.740129  0.013330 -0.911550
# 1    0.736393  2.389265  0.736667  0.015423 -1.218775
# 2    0.731969  2.251332  0.709717  0.013156 -1.122496
# 3    0.735015  2.388274  0.736197  0.014977 -1.214580
# 4    0.725872  2.448004  0.737060  0.012857 -0.697603
# ..        ...       ...       ...       ...       ...
# 961  0.735045  2.165183  0.698091  0.013423 -1.164278
# 962  0.726631  2.204177  0.693080  0.011845 -0.626338
# 963  0.727602  2.113649  0.678026  0.011613 -0.634598
# 964  0.738150  2.251622  0.715140  0.014969 -1.198659
# 965  0.728880  2.491825  0.749115  0.013877 -1.037020
#
# [966 rows x 5 columns]

# %% [markdown]
# ### Data Plot

# %% [markdown]
# Plotting the data to have a better visualization of our data distribution and linearity.

# %% [markdown]
# #### Lift Coefficient Cl Plot

# %%
figcl = plt.figure(figsize = [6,6])
clplot = Axes3D(figcl)
clplot.scatter(df['M'], df['AoA'], df['Cl'])
clplot.set_xlabel('Mach Number')
clplot.set_ylabel('Angle of Attack (degree)')
clplot.set_zlabel('Cl')
plt.show()

plt.scatter(df['M'], df['Cl'], alpha = 0.3)
plt.xlabel('Mach Number')
plt.ylabel('Cl')
plt.title('Cl vs Mach Number')
plt.show()

plt.scatter(df['AoA'], df['Cl'], alpha = 0.3)
plt.xlabel('Angle of Attack (degree)')
plt.ylabel('Cl')
plt.title('Cl vs AoA')
plt.show()

# %% [markdown]
# #### Drag Coefficient Cd Plot

# %%
figcd = plt.figure(figsize = [6,6])
cdplot = Axes3D(figcd)
cdplot.scatter(df['M'], df['AoA'], df['Cd'], c = 'r', alpha = 0.3)
cdplot.set_xlabel('Mach Number')
cdplot.set_ylabel('Angle of Attack (degree)')
cdplot.set_zlabel('Cd')
plt.show()

plt.scatter(df['M'], df['Cd'], alpha = 0.2, c = 'r')
plt.xlabel('Mach Number')
plt.ylabel('Cd')
plt.title('Cd vs Mach Number')
plt.show()

plt.scatter(df['AoA'], df['Cd'], alpha = 0.2, c = 'r')
plt.xlabel('Angle of Attack (degree)')
plt.ylabel('Cd')
plt.title('Cd vs AoA')
plt.show()

# %% [markdown]
# #### Pressure Coefficient Cp Plot

# %%
figcp = plt.figure(figsize = [6,6])
cpplot = Axes3D(figcp)
cpplot.scatter(df['M'], df['AoA'], df['Cp'], c = 'g')
cpplot.set_xlabel('Mach Number')
cpplot.set_ylabel('Angle of Attack (degree)')
cpplot.set_zlabel('Cp')
plt.show()

plt.scatter(df['M'], df['Cp'], alpha = 0.3, c = 'g')
plt.xlabel('Mach Number')
plt.ylabel('Cp')
plt.title('Cp vs Mach Number')
plt.show()

plt.scatter(df['AoA'], df['Cp'], alpha = 0.3, c = 'g')
plt.xlabel('Angle of Attack (degree)')
plt.ylabel('Cp')
plt.title('Cp vs AoA')
plt.show()

# %% [markdown]
# ### Correlation Coefficient

# %% [markdown]
# Checking the Pearson's correlation coefficient to measure the statistical relationship, or association, between the variables.

# %%
df_heatmap = sns.heatmap(df.corr(), annot = True, cmap = 'coolwarm')

# %% [markdown]
# ### Input and Output Data
# Defining the input data and the output data.

# %%
X = df.loc[:, ['M', 'AoA']]
y = df.loc[:, ['Cl', 'Cd', 'Cp']]

# %%
X #Input Data
# Out:
#             M       AoA
# 0    0.727928  2.449037
# 1    0.736393  2.389265
# 2    0.731969  2.251332
# 3    0.735015  2.388274
# 4    0.725872  2.448004
# ..        ...       ...
# 961  0.735045  2.165183
# 962  0.726631  2.204177
# 963  0.727602  2.113649
# 964  0.738150  2.251622
# 965  0.728880  2.491825
#
# [966 rows x 2 columns]

# %%
y #Output Data
# Out:
#            Cl        Cd        Cp
# 0    0.740129  0.013330 -0.911550
# 1    0.736667  0.015423 -1.218775
# 2    0.709717  0.013156 -1.122496
# 3    0.736197  0.014977 -1.214580
# 4    0.737060  0.012857 -0.697603
# ..        ...       ...       ...
# 961  0.698091  0.013423 -1.164278
# 962  0.693080  0.011845 -0.626338
# 963  0.678026  0.011613 -0.634598
# 964  0.715140  0.014969 -1.198659
# 965  0.749115  0.013877 -1.037020
#
# [966 rows x 3 columns]

# %% [markdown]
# ### Dataset Split (Training and Validation Data)
# Splitting the dataset by random and evenly distributed for the training and validation dataset.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 29)

# %% [markdown]
# Plotting to visualize the dataset split result.

# %%
# Creating figure
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(X_train['M'], X_train['AoA'], y_train['Cl'], color = "green", alpha=0.3, label='Train Data')
visual_split.scatter3D(X_test['M'], X_test['AoA'], y_test['Cl'], color = "red",alpha=0.5, label='Test Data')
plt.title("Train and Test Dataset")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

# %% [markdown]
# ## Normalizing The Data

# %% [markdown]
# Normalization ensures that the magnitude of the values that a feature assumes are more or less the same.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scalery = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

y_train = scalery.fit_transform(y_train)
y_test = scalery.transform(y_test)

# %% [markdown]
# ## Modeling The Artificial Neural Network

# %% [markdown]
# The activation function for the hidden layer of the network is using the Rectified Linear Unit (ReLU) function as it is a simple, fast and observed to converge much more quickly and reliably.
#
# The Dropout algorithm is commented out as it doesn't provide improvements after a few trainings, and early stopping method is being used instead to avoid overfitting our neural network to the dataset.
#
# The optimizer is the adam optimizer as it provides an adaptive learning rate to optimize better.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
NNmodel = Sequential()

NNmodel.add(Dense(6,activation='relu')) #Hidden Layer
#NNmodel.add(Dropout(0.2))
NNmodel.add(Dense(6,activation='relu')) #Hidden Layer
#NNmodel.add(Dropout(0.2))
NNmodel.add(Dense(6,activation='relu')) #Hidden Layer
#NNmodel.add(Dropout(0.2))

NNmodel.add(Dense(units = 3,activation='linear')) #Output Layer

NNmodel.compile(loss='mse', optimizer='adam')

# %% [markdown]
# ### Early Stopping

# %% [markdown]
# To avoid overfitting during the training of the neural network, early stopping method is being added. Early stopping is a form of regularization used to avoid overfitting when training a learner with an iterative method.

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)

# %% [markdown]
# ### Training The Artificial Neural Network

# %%
NNmodel.fit(x=X_train, y=y_train, epochs=1000, validation_data=(X_test,y_test), callbacks=[early_stop])
# Out:
# Epoch 1/1000
# 25/25 [==============================] - 1s 7ms/step - loss: 0.1775 - val_loss: 0.1306
# Epoch 2/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1086 - val_loss: 0.0867
# Epoch 3/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0800 - val_loss: 0.0713
# Epoch 4/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0664 - val_loss: 0.0667
# Epoch 5/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0613 - val_loss: 0.0639
# Epoch 6/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0594 - val_loss: 0.0619
# Epoch 7/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0554 - val_loss: 0.0602
# Epoch 8/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0564 - val_loss: 0.0586
# Epoch 9/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0538 - val_loss: 0.0571
# Epoch 10/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0522 - val_loss: 0.0556
# Epoch 11/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0523 - val_loss: 0.0541
# Epoch 12/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0500 - val_loss: 0.0525
# Epoch 13/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0499 - val_loss: 0.0511
# Epoch 14/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0472 - val_loss: 0.0496
# Epoch 15/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0454 - val_loss: 0.0481
# Epoch 16/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0457 - val_loss: 0.0467
# Epoch 17/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0432 - val_loss: 0.0453
# Epoch 18/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0421 - val_loss: 0.0439
# Epoch 19/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0423 - val_loss: 0.0425
# Epoch 20/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0403 - val_loss: 0.0412
# Epoch 21/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0375 - val_loss: 0.0397
# Epoch 22/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0369 - val_loss: 0.0384
# Epoch 23/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0381 - val_loss: 0.0370
# Epoch 24/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0331 - val_loss: 0.0356
# Epoch 25/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0316 - val_loss: 0.0340
# Epoch 26/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0324 - val_loss: 0.0323
# Epoch 27/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0300 - val_loss: 0.0307
# Epoch 28/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0283 - val_loss: 0.0292
# Epoch 29/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0283 - val_loss: 0.0274
# Epoch 30/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0265 - val_loss: 0.0256
# Epoch 31/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0249 - val_loss: 0.0241
# Epoch 32/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0232 - val_loss: 0.0222
# Epoch 33/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0213 - val_loss: 0.0203
# Epoch 34/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0175 - val_loss: 0.0185
# Epoch 35/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0168 - val_loss: 0.0167
# Epoch 36/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0152 - val_loss: 0.0151
# Epoch 37/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0141 - val_loss: 0.0135
# Epoch 38/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0116 - val_loss: 0.0121
# Epoch 39/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0099 - val_loss: 0.0108
# Epoch 40/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0091 - val_loss: 0.0097
# Epoch 41/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.0086
# Epoch 42/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0077 - val_loss: 0.0078
# Epoch 43/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0073
# Epoch 44/1000
# 25/25 [==============================] - ETA: 0s - loss: 0.005 - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0065
# Epoch 45/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0060
# Epoch 46/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 47/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0052
# Epoch 48/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0049
# Epoch 49/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0046
# Epoch 50/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0043
# Epoch 51/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 52/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 53/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0039
# Epoch 54/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 55/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0038
# Epoch 56/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 57/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 58/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 59/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0034
# Epoch 60/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 61/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 62/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 63/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 64/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 65/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 66/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 67/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 68/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 69/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 70/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 71/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 72/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 73/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 74/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 75/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 76/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 77/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 78/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 79/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 80/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 81/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 82/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 83/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 84/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 85/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 86/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 87/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 88/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 89/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 90/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 91/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 92/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 93/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 94/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 95/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 96/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 97/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 98/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 99/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 100/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 101/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 102/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 103/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 104/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 105/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 106/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 107/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 108/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 109/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 110/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 111/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 112/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 113/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 114/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 115/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 116/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 117/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 118/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 119/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 120/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 121/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 122/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 123/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 124/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 125/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 126/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 127/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 128/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 129/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 130/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 131/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 132/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.5577e-04 - val_loss: 0.0013
# Epoch 133/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 134/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 135/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.4314e-04 - val_loss: 0.0013
# Epoch 136/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.3764e-04 - val_loss: 0.0012
# Epoch 137/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 138/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 9.8749e-04 - val_loss: 0.0012
# Epoch 139/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.2239e-04 - val_loss: 0.0012
# Epoch 140/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.9910e-04 - val_loss: 0.0012
# Epoch 141/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.9631e-04 - val_loss: 0.0012
# Epoch 142/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.7477e-04 - val_loss: 0.0012
# Epoch 143/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.3072e-04 - val_loss: 0.0012
# Epoch 144/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.2525e-04 - val_loss: 0.0012
# Epoch 145/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.6194e-04 - val_loss: 0.0012
# Epoch 146/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 7.7908e-04 - val_loss: 0.0011
# Epoch 147/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.1684e-04 - val_loss: 0.0012
# Epoch 148/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.7268e-04 - val_loss: 0.0011
# Epoch 149/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.5049e-04 - val_loss: 0.0011
# Epoch 150/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.6704e-04 - val_loss: 0.0011
# Epoch 151/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.6152e-04 - val_loss: 0.0011
# Epoch 152/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.9601e-04 - val_loss: 0.0011
# Epoch 153/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.6752e-04 - val_loss: 0.0011
# Epoch 154/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.8859e-04 - val_loss: 0.0011
# Epoch 155/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 9.3524e-04 - val_loss: 0.0011
# Epoch 156/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.0354e-04 - val_loss: 0.0011
# Epoch 157/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.9858e-04 - val_loss: 0.0011
# Epoch 158/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 159/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.9929e-04 - val_loss: 0.0011
# Epoch 160/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.2246e-04 - val_loss: 0.0011
# Epoch 161/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.6913e-04 - val_loss: 0.0010
# Epoch 162/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.9198e-04 - val_loss: 0.0010
# Epoch 163/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.9630e-04 - val_loss: 0.0010
# Epoch 164/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.6605e-04 - val_loss: 0.0010
# Epoch 165/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.4509e-04 - val_loss: 0.0010
# Epoch 166/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.0319e-04 - val_loss: 0.0010
# Epoch 167/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.5406e-04 - val_loss: 0.0010
# Epoch 168/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.9200e-04 - val_loss: 0.0010
# Epoch 169/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.5145e-04 - val_loss: 9.9958e-04
# Epoch 170/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.1270e-04 - val_loss: 9.9934e-04
# Epoch 171/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.2166e-04 - val_loss: 9.8728e-04
# Epoch 172/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.0581e-04 - val_loss: 9.8320e-04
# Epoch 173/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.6960e-04 - val_loss: 9.8351e-04
# Epoch 174/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.1692e-04 - val_loss: 9.7151e-04
# Epoch 175/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.8295e-04 - val_loss: 9.8369e-04
# Epoch 176/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.2676e-04 - val_loss: 9.6377e-04
# Epoch 177/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.6188e-04 - val_loss: 9.5720e-04
# Epoch 178/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.6448e-04 - val_loss: 9.4799e-04
# Epoch 179/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.4889e-04 - val_loss: 9.4340e-04
# Epoch 180/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.5232e-04 - val_loss: 9.4094e-04
# Epoch 181/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.9410e-04 - val_loss: 9.2729e-04
# Epoch 182/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.7137e-04 - val_loss: 9.1767e-04
# Epoch 183/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.0803e-04 - val_loss: 9.1144e-04
# Epoch 184/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 8.2042e-04 - val_loss: 9.1308e-04
# Epoch 185/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.1797e-04 - val_loss: 9.0883e-04
# Epoch 186/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.1112e-04 - val_loss: 9.5321e-04
# Epoch 187/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.6872e-04 - val_loss: 8.8886e-04
# Epoch 188/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.6749e-04 - val_loss: 8.8788e-04
# Epoch 189/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.0036e-04 - val_loss: 8.7774e-04
# Epoch 190/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.3151e-04 - val_loss: 8.7653e-04
# Epoch 191/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.3052e-04 - val_loss: 8.6404e-04
# Epoch 192/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 7.6550e-04 - val_loss: 8.5526e-04
# Epoch 193/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.5248e-04 - val_loss: 8.5574e-04
# Epoch 194/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.4101e-04 - val_loss: 8.3829e-04
# Epoch 195/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.4295e-04 - val_loss: 8.3781e-04
# Epoch 196/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.7172e-04 - val_loss: 8.2777e-04
# Epoch 197/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.2484e-04 - val_loss: 8.2485e-04
# Epoch 198/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.0499e-04 - val_loss: 8.1340e-04
# Epoch 199/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.0856e-04 - val_loss: 8.1002e-04
# Epoch 200/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.1027e-04 - val_loss: 7.9943e-04
# Epoch 201/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.3660e-04 - val_loss: 7.9559e-04
# Epoch 202/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.1536e-04 - val_loss: 7.8696e-04
# Epoch 203/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.0586e-04 - val_loss: 7.8218e-04
# Epoch 204/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.2951e-04 - val_loss: 7.7497e-04
# Epoch 205/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.6757e-04 - val_loss: 7.6654e-04
# Epoch 206/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.0067e-04 - val_loss: 7.6395e-04
# Epoch 207/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.1751e-04 - val_loss: 7.5377e-04
# Epoch 208/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.6003e-04 - val_loss: 7.4638e-04
# Epoch 209/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 6.5320e-04 - val_loss: 7.4369e-04
# Epoch 210/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 5.4691e-04 - val_loss: 7.5302e-04
# Epoch 211/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.8519e-04 - val_loss: 7.2612e-04
# Epoch 212/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4109e-04 - val_loss: 7.2498e-04
# Epoch 213/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.8982e-04 - val_loss: 7.1916e-04
# Epoch 214/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0024e-04 - val_loss: 7.1166e-04
# Epoch 215/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.5180e-04 - val_loss: 6.9678e-04
# Epoch 216/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.3722e-04 - val_loss: 6.9123e-04
# Epoch 217/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.6531e-04 - val_loss: 6.7884e-04
# Epoch 218/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.6374e-04 - val_loss: 6.7984e-04
# Epoch 219/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.9828e-04 - val_loss: 6.6439e-04
# Epoch 220/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4885e-04 - val_loss: 6.6681e-04
# Epoch 221/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.5444e-04 - val_loss: 6.7051e-04
# Epoch 222/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.5798e-04 - val_loss: 6.5298e-04
# Epoch 223/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.3689e-04 - val_loss: 6.3513e-04
# Epoch 224/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0807e-04 - val_loss: 6.4459e-04
# Epoch 225/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0973e-04 - val_loss: 6.2385e-04
# Epoch 226/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.9288e-04 - val_loss: 6.1787e-04
# Epoch 227/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.9351e-04 - val_loss: 6.0955e-04
# Epoch 228/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.9669e-04 - val_loss: 6.0338e-04
# Epoch 229/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.8083e-04 - val_loss: 6.0374e-04
# Epoch 230/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.5533e-04 - val_loss: 5.9269e-04
# Epoch 231/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.6494e-04 - val_loss: 5.9657e-04
# Epoch 232/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.4336e-04 - val_loss: 5.8439e-04
# Epoch 233/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.8591e-04 - val_loss: 5.8411e-04
# Epoch 234/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.5048e-04 - val_loss: 5.6782e-04
# Epoch 235/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0679e-04 - val_loss: 5.5938e-04
# Epoch 236/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.1997e-04 - val_loss: 5.5852e-04
# Epoch 237/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.8384e-04 - val_loss: 5.5314e-04
# Epoch 238/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 5.0400e-04 - val_loss: 5.4449e-04
# Epoch 239/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.9993e-04 - val_loss: 5.3536e-04
# Epoch 240/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.6144e-04 - val_loss: 5.3081e-04
# Epoch 241/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.4783e-04 - val_loss: 5.2671e-04
# Epoch 242/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.4442e-04 - val_loss: 5.2611e-04
# Epoch 243/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.0439e-04 - val_loss: 5.1872e-04
# Epoch 244/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.9996e-04 - val_loss: 5.0944e-04
# Epoch 245/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.1695e-04 - val_loss: 5.0270e-04
# Epoch 246/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.3465e-04 - val_loss: 4.9813e-04
# Epoch 247/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.7782e-04 - val_loss: 5.0631e-04
# Epoch 248/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.3176e-04 - val_loss: 4.9548e-04
# Epoch 249/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.9018e-04 - val_loss: 4.8633e-04
# Epoch 250/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.1987e-04 - val_loss: 4.9590e-04
# Epoch 251/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.2440e-04 - val_loss: 4.8930e-04
# Epoch 252/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.5501e-04 - val_loss: 4.7130e-04
# Epoch 253/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.3996e-04 - val_loss: 4.7232e-04
# Epoch 254/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.6085e-04 - val_loss: 4.6914e-04
# Epoch 255/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.8601e-04 - val_loss: 4.6716e-04
# Epoch 256/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.4433e-04 - val_loss: 4.6529e-04
# Epoch 257/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.0893e-04 - val_loss: 4.5671e-04
# Epoch 258/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.6956e-04 - val_loss: 4.5027e-04
# Epoch 259/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.3698e-04 - val_loss: 4.4697e-04
# Epoch 260/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.4784e-04 - val_loss: 4.3580e-04
# Epoch 261/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.7880e-04 - val_loss: 4.3347e-04
# Epoch 262/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.5935e-04 - val_loss: 4.2798e-04
# Epoch 263/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.2867e-04 - val_loss: 4.2133e-04
# Epoch 264/1000
# 25/25 [==============================] - ETA: 0s - loss: 3.0988e-0 - 0s 3ms/step - loss: 3.3906e-04 - val_loss: 4.1988e-04
# Epoch 265/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.5040e-04 - val_loss: 4.1300e-04
# Epoch 266/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.3903e-04 - val_loss: 4.1089e-04
# Epoch 267/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.4760e-04 - val_loss: 4.0644e-04
# Epoch 268/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.2755e-04 - val_loss: 4.2175e-04
# Epoch 269/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.1497e-04 - val_loss: 4.0290e-04
# Epoch 270/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.6212e-04 - val_loss: 4.0788e-04
# Epoch 271/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.4527e-04 - val_loss: 3.9889e-04
# Epoch 272/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.7737e-04 - val_loss: 3.9364e-04
# Epoch 273/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.3533e-04 - val_loss: 3.8508e-04
# Epoch 274/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.1416e-04 - val_loss: 3.8218e-04
# Epoch 275/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.9388e-04 - val_loss: 3.9294e-04
# Epoch 276/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.1861e-04 - val_loss: 3.7234e-04
# Epoch 277/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.1253e-04 - val_loss: 3.8291e-04
# Epoch 278/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 4.0700e-04 - val_loss: 3.7872e-04
# Epoch 279/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.3043e-04 - val_loss: 3.6405e-04
# Epoch 280/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.0143e-04 - val_loss: 3.6717e-04
# Epoch 281/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.7774e-04 - val_loss: 3.6048e-04
# Epoch 282/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.1262e-04 - val_loss: 3.5965e-04
# Epoch 283/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.2539e-04 - val_loss: 3.5653e-04
# Epoch 284/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.8878e-04 - val_loss: 3.5654e-04
# Epoch 285/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.7354e-04 - val_loss: 3.8267e-04
# Epoch 286/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 3.0137e-04 - val_loss: 3.4621e-04
# Epoch 287/1000
# 25/25 [==============================] - ETA: 0s - loss: 3.1849e-0 - 0s 3ms/step - loss: 2.8842e-04 - val_loss: 3.3613e-04
# Epoch 288/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.8804e-04 - val_loss: 3.3802e-04
# Epoch 289/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.7386e-04 - val_loss: 3.3524e-04
# Epoch 290/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.7129e-04 - val_loss: 3.7909e-04
# Epoch 291/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.9548e-04 - val_loss: 3.3447e-04
# Epoch 292/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.9973e-04 - val_loss: 3.2479e-04
# Epoch 293/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.7627e-04 - val_loss: 3.2821e-04
# Epoch 294/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.6550e-04 - val_loss: 3.2058e-04
# Epoch 295/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.8428e-04 - val_loss: 3.1936e-04
# Epoch 296/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.9102e-04 - val_loss: 3.1649e-04
# Epoch 297/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.6425e-04 - val_loss: 3.1170e-04
# Epoch 298/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.7911e-04 - val_loss: 3.1720e-04
# Epoch 299/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.8524e-04 - val_loss: 3.1504e-04
# Epoch 300/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.5715e-04 - val_loss: 3.1618e-04
# Epoch 301/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.7874e-04 - val_loss: 3.0669e-04
# Epoch 302/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.6658e-04 - val_loss: 2.9980e-04
# Epoch 303/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.7061e-04 - val_loss: 3.0933e-04
# Epoch 304/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.5974e-04 - val_loss: 2.9582e-04
# Epoch 305/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.9027e-04 - val_loss: 3.2040e-04
# Epoch 306/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.6730e-04 - val_loss: 3.1809e-04
# Epoch 307/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.5965e-04 - val_loss: 2.9500e-04
# Epoch 308/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.5225e-04 - val_loss: 2.8944e-04
# Epoch 309/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.5306e-04 - val_loss: 3.0495e-04
# Epoch 310/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.6042e-04 - val_loss: 2.8548e-04
# Epoch 311/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.7187e-04 - val_loss: 2.9268e-04
# Epoch 312/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.3381e-04 - val_loss: 2.8576e-04
# Epoch 313/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.3445e-04 - val_loss: 2.9478e-04
# Epoch 314/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.5256e-04 - val_loss: 2.8310e-04
# Epoch 315/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.3293e-04 - val_loss: 3.0593e-04
# Epoch 316/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.8252e-04 - val_loss: 2.8738e-04
# Epoch 317/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.4062e-04 - val_loss: 2.8339e-04
# Epoch 318/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2128e-04 - val_loss: 2.7934e-04
# Epoch 319/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.5682e-04 - val_loss: 2.9420e-04
# Epoch 320/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.8535e-04 - val_loss: 2.7377e-04
# Epoch 321/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.6038e-04 - val_loss: 2.6910e-04
# Epoch 322/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2264e-04 - val_loss: 2.8264e-04
# Epoch 323/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2283e-04 - val_loss: 2.6672e-04
# Epoch 324/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 2.1232e-04 - val_loss: 2.6460e-04
# Epoch 325/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 2.4118e-04 - val_loss: 2.7137e-04
# Epoch 326/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 2.3187e-04 - val_loss: 2.9014e-04
# Epoch 327/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 2.6053e-04 - val_loss: 2.6846e-04
# Epoch 328/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 2.3746e-04 - val_loss: 2.5742e-04
# Epoch 329/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 2.3524e-04 - val_loss: 2.6042e-04
# Epoch 330/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2954e-04 - val_loss: 2.5191e-04
# Epoch 331/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1081e-04 - val_loss: 2.6492e-04
# Epoch 332/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.3128e-04 - val_loss: 2.6105e-04
# Epoch 333/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2634e-04 - val_loss: 2.6300e-04
# Epoch 334/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.6065e-04 - val_loss: 2.5248e-04
# Epoch 335/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1248e-04 - val_loss: 2.5119e-04
# Epoch 336/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1531e-04 - val_loss: 2.5308e-04
# Epoch 337/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 2.4108e-04 - val_loss: 2.5271e-04
# Epoch 338/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2596e-04 - val_loss: 2.4617e-04
# Epoch 339/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 2.3031e-04 - val_loss: 2.4359e-04
# Epoch 340/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 2.1009e-04 - val_loss: 2.5424e-04
# Epoch 341/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 2.2189e-04 - val_loss: 2.5732e-04
# Epoch 342/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 2.1976e-04 - val_loss: 2.4030e-04
# Epoch 343/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1023e-04 - val_loss: 2.4617e-04
# Epoch 344/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2137e-04 - val_loss: 2.7220e-04
# Epoch 345/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.5350e-04 - val_loss: 2.4476e-04
# Epoch 346/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0281e-04 - val_loss: 2.3572e-04
# Epoch 347/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1791e-04 - val_loss: 2.4546e-04
# Epoch 348/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.3026e-04 - val_loss: 2.3406e-04
# Epoch 349/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.3008e-04 - val_loss: 2.3395e-04
# Epoch 350/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.3999e-04 - val_loss: 2.4030e-04
# Epoch 351/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.4656e-04 - val_loss: 2.4728e-04
# Epoch 352/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2351e-04 - val_loss: 2.4337e-04
# Epoch 353/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2630e-04 - val_loss: 2.3211e-04
# Epoch 354/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.3177e-04 - val_loss: 2.5763e-04
# Epoch 355/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1533e-04 - val_loss: 2.2832e-04
# Epoch 356/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1597e-04 - val_loss: 2.3640e-04
# Epoch 357/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2380e-04 - val_loss: 2.2652e-04
# Epoch 358/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2674e-04 - val_loss: 2.3589e-04
# Epoch 359/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.3327e-04 - val_loss: 2.2381e-04
# Epoch 360/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9540e-04 - val_loss: 2.2708e-04
# Epoch 361/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9736e-04 - val_loss: 2.2728e-04
# Epoch 362/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2801e-04 - val_loss: 2.4142e-04
# Epoch 363/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9640e-04 - val_loss: 2.1991e-04
# Epoch 364/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 2.0619e-04 - val_loss: 2.2433e-04
# Epoch 365/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8191e-04 - val_loss: 2.2624e-04
# Epoch 366/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0661e-04 - val_loss: 2.3160e-04
# Epoch 367/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2561e-04 - val_loss: 2.2573e-04
# Epoch 368/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1020e-04 - val_loss: 2.2534e-04
# Epoch 369/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9421e-04 - val_loss: 2.3259e-04
# Epoch 370/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9839e-04 - val_loss: 2.3734e-04
# Epoch 371/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2446e-04 - val_loss: 2.4221e-04
# Epoch 372/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8959e-04 - val_loss: 2.2564e-04
# Epoch 373/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2261e-04 - val_loss: 2.1660e-04
# Epoch 374/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9893e-04 - val_loss: 2.3443e-04
# Epoch 375/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0095e-04 - val_loss: 2.1518e-04
# Epoch 376/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0135e-04 - val_loss: 2.1687e-04
# Epoch 377/1000
# 25/25 [==============================] - 0s 5ms/step - loss: 2.1144e-04 - val_loss: 2.2029e-04
# Epoch 378/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0188e-04 - val_loss: 2.1201e-04
# Epoch 379/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2071e-04 - val_loss: 2.1481e-04
# Epoch 380/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7645e-04 - val_loss: 2.0815e-04
# Epoch 381/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1414e-04 - val_loss: 2.0937e-04
# Epoch 382/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8914e-04 - val_loss: 2.0392e-04
# Epoch 383/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0157e-04 - val_loss: 2.0779e-04
# Epoch 384/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8964e-04 - val_loss: 2.2091e-04
# Epoch 385/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8088e-04 - val_loss: 2.1717e-04
# Epoch 386/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9315e-04 - val_loss: 2.0864e-04
# Epoch 387/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0239e-04 - val_loss: 2.1144e-04
# Epoch 388/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1835e-04 - val_loss: 2.1895e-04
# Epoch 389/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8167e-04 - val_loss: 2.2933e-04
# Epoch 390/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1151e-04 - val_loss: 2.0128e-04
# Epoch 391/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8132e-04 - val_loss: 2.0756e-04
# Epoch 392/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9629e-04 - val_loss: 2.0198e-04
# Epoch 393/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8951e-04 - val_loss: 2.1644e-04
# Epoch 394/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8901e-04 - val_loss: 2.0121e-04
# Epoch 395/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8815e-04 - val_loss: 1.9655e-04
# Epoch 396/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6919e-04 - val_loss: 1.9986e-04
# Epoch 397/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1387e-04 - val_loss: 1.9846e-04
# Epoch 398/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8958e-04 - val_loss: 1.9938e-04
# Epoch 399/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8753e-04 - val_loss: 1.9884e-04
# Epoch 400/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8826e-04 - val_loss: 1.9711e-04
# Epoch 401/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6930e-04 - val_loss: 2.0289e-04
# Epoch 402/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8522e-04 - val_loss: 1.9708e-04
# Epoch 403/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2872e-04 - val_loss: 2.0501e-04
# Epoch 404/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8748e-04 - val_loss: 1.9323e-04
# Epoch 405/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6990e-04 - val_loss: 1.9581e-04
# Epoch 406/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0377e-04 - val_loss: 1.9448e-04
# Epoch 407/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8038e-04 - val_loss: 1.9527e-04
# Epoch 408/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7625e-04 - val_loss: 1.9603e-04
# Epoch 409/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8217e-04 - val_loss: 2.1226e-04
# Epoch 410/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7782e-04 - val_loss: 2.3299e-04
# Epoch 411/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6180e-04 - val_loss: 1.9247e-04
# Epoch 412/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7970e-04 - val_loss: 2.0058e-04
# Epoch 413/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8364e-04 - val_loss: 1.9110e-04
# Epoch 414/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9136e-04 - val_loss: 1.8734e-04
# Epoch 415/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0529e-04 - val_loss: 2.1135e-04
# Epoch 416/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7514e-04 - val_loss: 1.9051e-04
# Epoch 417/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7072e-04 - val_loss: 1.9336e-04
# Epoch 418/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7839e-04 - val_loss: 1.9171e-04
# Epoch 419/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9127e-04 - val_loss: 1.8650e-04
# Epoch 420/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9829e-04 - val_loss: 1.9627e-04
# Epoch 421/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6023e-04 - val_loss: 1.8533e-04
# Epoch 422/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7787e-04 - val_loss: 1.9061e-04
# Epoch 423/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6861e-04 - val_loss: 1.9249e-04
# Epoch 424/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7766e-04 - val_loss: 1.9513e-04
# Epoch 425/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7216e-04 - val_loss: 1.9666e-04
# Epoch 426/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8387e-04 - val_loss: 1.8330e-04
# Epoch 427/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7538e-04 - val_loss: 1.9184e-04
# Epoch 428/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8841e-04 - val_loss: 1.9094e-04
# Epoch 429/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5813e-04 - val_loss: 1.8647e-04
# Epoch 430/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6436e-04 - val_loss: 1.8532e-04
# Epoch 431/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1031e-04 - val_loss: 1.7975e-04
# Epoch 432/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6385e-04 - val_loss: 1.8645e-04
# Epoch 433/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8514e-04 - val_loss: 2.0665e-04
# Epoch 434/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8229e-04 - val_loss: 1.8940e-04
# Epoch 435/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7296e-04 - val_loss: 1.8813e-04
# Epoch 436/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7337e-04 - val_loss: 2.0300e-04
# Epoch 437/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8763e-04 - val_loss: 1.9621e-04
# Epoch 438/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8083e-04 - val_loss: 1.9289e-04
# Epoch 439/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8052e-04 - val_loss: 2.4239e-04
# Epoch 440/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0947e-04 - val_loss: 1.7782e-04
# Epoch 441/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8523e-04 - val_loss: 1.8300e-04
# Epoch 442/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7052e-04 - val_loss: 1.9493e-04
# Epoch 443/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5444e-04 - val_loss: 1.9370e-04
# Epoch 444/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8506e-04 - val_loss: 1.9070e-04
# Epoch 445/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0361e-04 - val_loss: 1.8053e-04
# Epoch 446/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5671e-04 - val_loss: 1.9894e-04
# Epoch 447/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6876e-04 - val_loss: 1.8528e-04
# Epoch 448/1000
# ...
# Epoch 485/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7610e-04 - val_loss: 1.6997e-04
# Epoch 486/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6254e-04 - val_loss: 1.7392e-04
# Epoch 487/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.5411e-0 - 0s 3ms/step - loss: 1.5669e-04 - val_loss: 1.7578e-04
# Epoch 488/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7178e-04 - val_loss: 1.6905e-04
# Epoch 489/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4382e-04 - val_loss: 2.1669e-04
# Epoch 490/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8065e-04 - val_loss: 1.8267e-04
# Epoch 491/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6913e-04 - val_loss: 1.9457e-04
# Epoch 492/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5758e-04 - val_loss: 1.7761e-04
# Epoch 493/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6006e-04 - val_loss: 1.8006e-04
# Epoch 494/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6769e-04 - val_loss: 1.8373e-04
# Epoch 495/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9218e-04 - val_loss: 1.6837e-04
# Epoch 496/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6133e-04 - val_loss: 1.7105e-04
# Epoch 497/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5376e-04 - val_loss: 1.7958e-04
# Epoch 498/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8911e-04 - val_loss: 1.6952e-04
# Epoch 499/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7848e-04 - val_loss: 1.6877e-04
# Epoch 500/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3989e-04 - val_loss: 1.7063e-04
# Epoch 501/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6789e-04 - val_loss: 1.7082e-04
# Epoch 502/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7558e-04 - val_loss: 1.8032e-04
# Epoch 503/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.7269e-04 - val_loss: 1.6807e-04
# Epoch 504/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4854e-04 - val_loss: 1.7139e-04
# Epoch 505/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8837e-04 - val_loss: 1.7239e-04
# Epoch 506/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8360e-04 - val_loss: 1.6746e-04
# Epoch 507/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4649e-04 - val_loss: 1.6753e-04
# Epoch 508/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5717e-04 - val_loss: 1.6862e-04
# Epoch 509/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6181e-04 - val_loss: 1.7686e-04
# Epoch 510/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7761e-04 - val_loss: 1.7039e-04
# Epoch 511/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8385e-04 - val_loss: 1.7204e-04
# Epoch 512/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7207e-04 - val_loss: 1.8895e-04
# Epoch 513/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6704e-04 - val_loss: 1.6801e-04
# Epoch 514/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8083e-04 - val_loss: 1.6954e-04
# Epoch 515/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.5924e-04 - val_loss: 1.7126e-04
# Epoch 516/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6205e-04 - val_loss: 1.6606e-04
# Epoch 517/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6113e-04 - val_loss: 1.6851e-04
# Epoch 518/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6058e-04 - val_loss: 2.1260e-04
# Epoch 519/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7477e-04 - val_loss: 1.6557e-04
# Epoch 520/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5698e-04 - val_loss: 1.7078e-04
# Epoch 521/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6061e-04 - val_loss: 1.7336e-04
# Epoch 522/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.6735e-04 - val_loss: 1.8055e-04
# Epoch 523/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.5979e-04 - val_loss: 1.7933e-04
# Epoch 524/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.5298e-04 - val_loss: 1.6626e-04
# Epoch 525/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.4714e-04 - val_loss: 1.8769e-04
# Epoch 526/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9479e-04 - val_loss: 1.6568e-04
# Epoch 527/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.5485e-04 - val_loss: 1.6514e-04
# Epoch 528/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.5472e-04 - val_loss: 1.6488e-04
# Epoch 529/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5921e-04 - val_loss: 1.6504e-04
# Epoch 530/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.5328e-04 - val_loss: 1.8589e-04
# Epoch 531/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.7499e-04 - val_loss: 1.6666e-04
# Epoch 532/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5875e-04 - val_loss: 1.8041e-04
# Epoch 533/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8968e-04 - val_loss: 1.6535e-04
# Epoch 534/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5402e-04 - val_loss: 1.6291e-04
# Epoch 535/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 1.6413e-04 - val_loss: 1.7239e-04
# Epoch 536/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6508e-04 - val_loss: 1.8252e-04
# Epoch 537/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7161e-04 - val_loss: 1.7748e-04
# Epoch 538/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7765e-04 - val_loss: 1.6376e-04
# Epoch 539/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4095e-04 - val_loss: 1.7726e-04
# Epoch 540/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6770e-04 - val_loss: 1.7832e-04
# Epoch 541/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7380e-04 - val_loss: 1.8437e-04
# Epoch 542/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6265e-04 - val_loss: 1.7153e-04
# Epoch 543/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6750e-04 - val_loss: 1.6439e-04
# Epoch 544/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5946e-04 - val_loss: 1.7073e-04
# Epoch 545/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8060e-04 - val_loss: 1.7775e-04
# Epoch 546/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5444e-04 - val_loss: 1.7244e-04
# Epoch 547/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6156e-04 - val_loss: 1.6636e-04
# Epoch 548/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5224e-04 - val_loss: 1.6418e-04
# Epoch 549/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5549e-04 - val_loss: 1.7662e-04
# Epoch 550/1000
# 25/25 [==============================] - ETA: 0s - loss: 1.4171e-0 - 0s 3ms/step - loss: 1.6075e-04 - val_loss: 1.9576e-04
# Epoch 551/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6248e-04 - val_loss: 1.7597e-04
# Epoch 552/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5173e-04 - val_loss: 1.6404e-04
# Epoch 553/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6082e-04 - val_loss: 1.8099e-04
# Epoch 554/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7822e-04 - val_loss: 1.7575e-04
# Epoch 555/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7224e-04 - val_loss: 1.6913e-04
# Epoch 556/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5894e-04 - val_loss: 1.6202e-04
# Epoch 557/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5347e-04 - val_loss: 1.6566e-04
# Epoch 558/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7707e-04 - val_loss: 1.6779e-04
# Epoch 559/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6355e-04 - val_loss: 1.6988e-04
# Epoch 560/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5502e-04 - val_loss: 1.6983e-04
# Epoch 561/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5135e-04 - val_loss: 1.7491e-04
# Epoch 562/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9604e-04 - val_loss: 1.6145e-04
# Epoch 563/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7768e-04 - val_loss: 1.6623e-04
# Epoch 564/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7673e-04 - val_loss: 1.8824e-04
# Epoch 565/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8996e-04 - val_loss: 2.4368e-04
# Epoch 566/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2342e-04 - val_loss: 2.1397e-04
# Epoch 567/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8044e-04 - val_loss: 1.6727e-04
# Epoch 568/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5098e-04 - val_loss: 1.6558e-04
# Epoch 569/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4257e-04 - val_loss: 2.3556e-04
# Epoch 570/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8797e-04 - val_loss: 2.1713e-04
# Epoch 571/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8113e-04 - val_loss: 2.0365e-04
# Epoch 572/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6598e-04 - val_loss: 1.6342e-04
# Epoch 573/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6193e-04 - val_loss: 1.6083e-04
# Epoch 574/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6175e-04 - val_loss: 1.7155e-04
# Epoch 575/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6611e-04 - val_loss: 1.6689e-04
# Epoch 576/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6130e-04 - val_loss: 1.6195e-04
# Epoch 577/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5235e-04 - val_loss: 1.6695e-04
# Epoch 578/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8271e-04 - val_loss: 1.6130e-04
# Epoch 579/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6469e-04 - val_loss: 1.7611e-04
# Epoch 580/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6589e-04 - val_loss: 1.7343e-04
# Epoch 581/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5880e-04 - val_loss: 1.6217e-04
# Epoch 582/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6118e-04 - val_loss: 1.6261e-04
# Epoch 583/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6523e-04 - val_loss: 1.6820e-04
# Epoch 584/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5609e-04 - val_loss: 1.6515e-04
# Epoch 585/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7397e-04 - val_loss: 1.6773e-04
# Epoch 586/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6062e-04 - val_loss: 1.6467e-04
# Epoch 587/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6396e-04 - val_loss: 1.7158e-04
# Epoch 588/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4012e-04 - val_loss: 2.2333e-04
# Epoch 589/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9183e-04 - val_loss: 2.0720e-04
# Epoch 590/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7523e-04 - val_loss: 1.7488e-04
# Epoch 591/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7470e-04 - val_loss: 1.6899e-04
# Epoch 592/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4890e-04 - val_loss: 1.7220e-04
# Epoch 593/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5725e-04 - val_loss: 1.6239e-04
# Epoch 594/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3939e-04 - val_loss: 1.6988e-04
# Epoch 595/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4853e-04 - val_loss: 1.6430e-04
# Epoch 596/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5457e-04 - val_loss: 1.5939e-04
# Epoch 597/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5014e-04 - val_loss: 1.8029e-04
# Epoch 598/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5082e-04 - val_loss: 1.5744e-04
# Epoch 599/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8322e-04 - val_loss: 1.6504e-04
# Epoch 600/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5442e-04 - val_loss: 1.6101e-04
# Epoch 601/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7499e-04 - val_loss: 1.5941e-04
# Epoch 602/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5018e-04 - val_loss: 1.6021e-04
# Epoch 603/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8713e-04 - val_loss: 1.5790e-04
# Epoch 604/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5578e-04 - val_loss: 2.1423e-04
# Epoch 605/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1104e-04 - val_loss: 1.8267e-04
# Epoch 606/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7020e-04 - val_loss: 1.6433e-04
# Epoch 607/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5889e-04 - val_loss: 1.5778e-04
# Epoch 608/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5231e-04 - val_loss: 1.5927e-04
# Epoch 609/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4996e-04 - val_loss: 1.6542e-04
# Epoch 610/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5346e-04 - val_loss: 1.6910e-04
# Epoch 611/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4905e-04 - val_loss: 1.6897e-04
# Epoch 612/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5022e-04 - val_loss: 1.5987e-04
# Epoch 613/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7731e-04 - val_loss: 1.6684e-04
# Epoch 614/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6207e-04 - val_loss: 1.8471e-04
# Epoch 615/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5797e-04 - val_loss: 1.8045e-04
# Epoch 616/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6927e-04 - val_loss: 1.6186e-04
# Epoch 617/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5472e-04 - val_loss: 1.6137e-04
# Epoch 618/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5895e-04 - val_loss: 1.5772e-04
# Epoch 619/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6747e-04 - val_loss: 1.9274e-04
# Epoch 620/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6925e-04 - val_loss: 1.7017e-04
# Epoch 621/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4673e-04 - val_loss: 1.6187e-04
# Epoch 622/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6817e-04 - val_loss: 1.6649e-04
# Epoch 623/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5368e-04 - val_loss: 2.3408e-04
# Epoch 624/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1115e-04 - val_loss: 1.8872e-04
# Epoch 625/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8755e-04 - val_loss: 1.7103e-04
# Epoch 626/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6356e-04 - val_loss: 1.6467e-04
# Epoch 627/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4261e-04 - val_loss: 1.5865e-04
# Epoch 628/1000
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4666e-04 - val_loss: 1.6185e-04
# Epoch 00628: early stopping

# %% [markdown]
# ### Plotting The Losses During Training

# %%
losses = pd.DataFrame(NNmodel.history.history)
losses[['loss', 'val_loss']].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Predicting On The Test Dataset

# %%
predictions = NNmodel.predict(X_test)

# %%
predictions = scalery.inverse_transform(predictions)
y_test = scalery.inverse_transform(y_test)

# %% [markdown]
# ### Mean Squared Error and Mean Absolute Error of the Prediction Results

# %%
mse_cl = mean_squared_error(y_test[:,0], predictions[:,0])
print(f"Mean Squared Error for Cl: {mse_cl}")
mae_cl = np.sum(np.absolute(y_test[:,0]- predictions[:,0]))/len(y_test)
print(f"Mean Absolute Error for Cl: {mae_cl}\n")
mse_cd = mean_squared_error(y_test[:,1], predictions[:,1])
print(f"Mean Squared Error for Cd: {mse_cd}")
mae_cd = np.sum(np.absolute(y_test[:,1]- predictions[:,1]))/len(y_test)
print(f"Mean Absolute Error for Cd: {mae_cd}\n")
mse_cp = mean_squared_error(y_test[:,2], predictions[:,2])
print(f"Mean Squared Error for Cp: {mse_cp}")
mae_cp = np.sum(np.absolute(y_test[:,2]- predictions[:,2]))/len(y_test)
print(f"Mean Absolute Error for Cp: {mae_cp}\n")
# Out:
# Mean Squared Error for Cl: 1.1385010905912334e-06
# Mean Absolute Error for Cl: 0.0006807357016494572
#
# Mean Squared Error for Cd: 2.3707785224956334e-08
# Mean Absolute Error for Cd: 0.00011280705475653575
#
# Mean Squared Error for Cp: 0.00011949675232382328
# Mean Absolute Error for Cp: 0.00850572284682755

# %% [markdown]
# ### Predictions vs Ground Truth Plots

# %%
###############################Cl
# Creating figure Cl
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], predictions[:,0], color = "black", alpha=1, label='Predictions', marker='x')
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], y_test[:,0], color = "blue", alpha=0.6, label='Ground Truth')
plt.title("Cl Prediction vs Ground Truth")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,0], predictions[:,0], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,0], y_test[:,0], color = "blue", alpha=0.6, label='Ground Truth')
plt.xlabel('Mach Number')
plt.ylabel('Cl')
plt.title('Cl vs Mach Number')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,1], predictions[:,0], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,1], y_test[:,0], color = "blue", alpha=0.6, label='Ground Truth')
plt.xlabel('AoA')
plt.ylabel('Cl')
plt.title('Cl vs AoA')
plt.legend()
plt.show()

##############################Cd
# Creating figure Cd
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], predictions[:,1], color = "black", alpha=1, label='Predictions', marker='x')
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], y_test[:,1], color = "red", alpha=0.6, label='Ground Truth')
plt.title("Cd Prediction vs Ground Truth")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,0], predictions[:,1], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,0], y_test[:,1], color = "red", alpha=0.6, label='Ground Truth')
plt.xlabel('Mach Number')
plt.ylabel('Cd')
plt.title('Cd vs Mach Number')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,1], predictions[:,1], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,1], y_test[:,1], color = "red", alpha=0.6, label='Ground Truth')
plt.xlabel('AoA')
plt.ylabel('Cd')
plt.title('Cd vs AoA')
plt.legend()
plt.show()

##############################Cp
# Creating figure Cp
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], predictions[:,2], color = "black", alpha=1, label='Predictions', marker='x')
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], y_test[:,2], color = "g", alpha=0.6, label='Ground Truth')
plt.title("Cp Prediction vs Ground Truth")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,0], predictions[:,2], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,0], y_test[:,2], color = "green", alpha=0.6, label='Ground Truth')
plt.xlabel('Mach Number')
plt.ylabel('Cd')
plt.title('Cd vs Mach Number')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,1], predictions[:,2], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,1], y_test[:,2], color = "green", alpha=0.6, label='Ground Truth')
plt.xlabel('AoA')
plt.ylabel('Cd')
plt.title('Cd vs AoA')
plt.legend()
plt.show()

# %% [markdown]
# ### Sampling Predictions

# %%
sample_number = 6
#alldata=len(predictions)
print("[Cl Cd Cp]")
for i in range (sample_number):
    print(f"Sample Data {i+1}: {y_test[i]}")
    print(f"Prediction {i+1}: {predictions[i]}")
    error = np.abs(y_test[i]-predictions[i])
    print(f"error: {error}\n--------------------------------------------------")
# Out:
# [Cl Cd Cp]
# Sample Data 1: [ 0.683542  0.011203 -0.686882]
# Prediction 1: [ 0.6832099   0.01124115 -0.6832231 ]
# error: [3.32103912e-04 3.81472946e-05 3.65887168e-03]
# --------------------------------------------------
# Sample Data 2: [ 0.73528   0.013844 -1.152869]
# Prediction 2: [ 0.7350197   0.01391097 -1.1561996 ]
# error: [2.60316162e-04 6.69706506e-05 3.33057447e-03]
# --------------------------------------------------
# Sample Data 3: [ 0.675539  0.01153  -0.624721]
# Prediction 3: [ 0.6757807   0.01147041 -0.62771714]
# error: [2.41713558e-04 5.95927525e-05 2.99613734e-03]
# --------------------------------------------------
# Sample Data 4: [ 0.652789  0.010931 -0.671232]
# Prediction 4: [ 0.6528885   0.01090016 -0.6689952 ]
# error: [9.94768486e-05 3.08350456e-05 2.23679841e-03]
# --------------------------------------------------
# Sample Data 5: [ 0.723796  0.014562 -1.201687]
# Prediction 5: [ 0.72270465  0.01475545 -1.1933607 ]
# error: [0.00109135 0.00019345 0.00832631]
# --------------------------------------------------
# Sample Data 6: [ 0.729271  0.015041 -1.210357]
# Prediction 6: [ 0.7287539   0.01524091 -1.2056676 ]
# error: [0.00051708 0.00019991 0.00468939]
# --------------------------------------------------
